# %%
import tensorflow as tf
tf.config.experimental.set_visible_devices([], 'GPU')
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xlsxwriter

# %%
tf.random.set_seed(2)
np.random.seed(2)

# %%
class AdaptiveLayer(keras.layers.Layer):
    
    def __init__(self, units, structure=[2, 2], inner_hidden_activation=tf.nn.tanh, 
                 inner_out_activation=lambda x : x, skip_w=0.0):
        super().__init__()
        self.units = units
        self.structure = structure
        self.inner_hidden_activation = inner_hidden_activation
        self.inner_out_activation = inner_out_activation
        self.skip_w = skip_w
        
        
    def build(self, input_shape):
        self.outer_w = self.add_weight(shape=(input_shape[-1], self.units), initializer="random_normal")
        self.outer_b = self.add_weight(shape=(self.units), initializer="zeros")
        
        self.inner_w = []
        self.inner_b = []
        for i in range(len(self.structure)):
            if i == 0:
                self.inner_w.append(self.add_weight(shape=(self.units, 1, self.structure[i]), 
                                          initializer=tf.initializers.random_normal(stddev=1.5)))
            else:
                self.inner_w.append(self.add_weight(shape=(self.units, self.structure[i-1], self.structure[i]), 
                                          initializer=tf.initializers.random_normal(stddev=0.9)))
            
            self.inner_b.append(self.add_weight(shape=(self.units, 1, self.structure[i]), initializer="zeros"))
   

    def call(self, inputs):
        z = inputs @ self.outer_w + self.outer_b
        a = tf.expand_dims(tf.transpose(z), axis=-1)
        
        for i in range(len(self.structure)-1):
            a = a @ self.inner_w[i] + self.inner_b[i]
            a = self.inner_hidden_activation(a)
        
        if len(self.structure) > 0:
            a = a @ self.inner_w[-1] + self.inner_b[-1]
        
        a = tf.reshape(tf.transpose(a), shape=(len(inputs), self.units))
        a = self.inner_out_activation(a+z*self.skip_w)
        
        return a
        

    def activation_show(self, inputs):
        inner_z = tf.cast(tf.expand_dims(tf.transpose(inputs), axis=-1), dtype=tf.float32)
        a = tf.expand_dims(tf.transpose(inner_z), axis=-1)
        
        for i in range(len(self.structure)-1):
            a = a @ self.inner_w[i] + self.inner_b[i]
            a = self.inner_hidden_activation(a)
        
        a = a @ self.inner_w[-1] + self.inner_b[-1]
        
        a = tf.reshape(tf.transpose(a), shape=(len(inputs), self.units))
        a = self.inner_out_activation(a)
        
        return a

# %%
class AdaptiveLayerConv(keras.layers.Layer):
    
    def __init__(self, units, structure=[4, 8], split=2, inner_hidden_activation=tf.nn.tanh, 
                 inner_out_activation=lambda x : x, skip_w=0.9, noise=0.0):
        super().__init__()
        self.units = units
        self.structure = structure
        self.split = split
        self.inner_hidden_activation = inner_hidden_activation
        self.inner_out_activation = inner_out_activation
        self.skip_w = skip_w
        self.noise = noise
        
        
    def build(self, input_shape):
        
        self.outer_w = self.add_weight(shape=(self.split, input_shape[-1], self.units),
                                                  initializer="random_normal")
        self.outer_b = self.add_weight(shape=(self.split, self.units), initializer="zeros")
        
        self.inner_w = []
        for i in range(0, len(self.structure)):
            self.inner_w.append(keras.layers.Conv1D(self.structure[i], 1, 
                                                       activation=self.inner_hidden_activation))
            
        self.inner_w.append(keras.layers.AveragePooling1D(pool_size=self.split, data_format='channels_first'))      
        self.inner_w.append(keras.layers.Conv1D(self.units, 1)) 

   
    def call(self, inputs):
        z = []
        for i in range(0, self.split):
            noise = tf.random.truncated_normal(shape=(self.outer_b[i].shape))
            z.append(inputs @ self.outer_w[i] + self.outer_b[i] + noise*self.noise)
        
        a = tf.cast(z, dtype=tf.float32)
        z = tf.cast(z, dtype=tf.float32)
        
        for i in range(len(self.inner_w)-2):
            a = self.inner_w[i](a)
        
        if len(self.inner_w) > 0:
            a = self.inner_w[-2](tf.transpose(a))
            a = self.inner_w[-1](tf.transpose(a))
    
        a = tf.reshape(a, shape=(-1, self.units))
        z_skip = tf.reduce_sum(z, axis=0)/self.split     
        
        a = self.inner_out_activation(a + z_skip*self.skip_w)
        
        return a    

    def activation_show(self, inputs):
        tmp = []
        for i in range(0, self.units):
            tmp.append(inputs)
        
        tmp = tf.cast(tmp, dtype=tf.float32)
        a = tf.expand_dims(tf.transpose(tmp), axis=0)
            
        for i in range(len(self.inner_w)-2):
            a = self.inner_w[i](a)
             
        a = self.inner_w[len(self.inner_w)-1](a)
        a = tf.reshape(a, shape=(-1, self.units))
        a = self.inner_out_activation(a)
        
        return a

# %%
class AdaptiveModel(keras.Model):
    
    def __init__(self, l=[AdaptiveLayer(2), AdaptiveLayer(1)]):
        super().__init__()
        self.l = l

    def call(self, inputs):
        a = inputs
        for layer in self.l:
            a = layer(a)
        
        return a
        
    def activation_show(self, inputs):
        y = []
        
        for layer in self.l:
            tmp = layer.activation_show(inputs)
            
            for i in range(tmp.shape[-1]):
                y.append(tmp[:, i])
        
        return y

# %%
# dataset

data = pd.read_csv('../datasets/sonar_data.csv')
data = pd.DataFrame(data).to_numpy()
np.random.shuffle(data)

x = data[:, :-1]
y = data[:, -1]

x = np.array(x, dtype=np.float32)
y = np.array([out == 'M' for out in (y)], dtype=np.float32)

x_train, x_test = x[:160, :], x[160:, :]
y_train, y_test = y[:160], y[160:]

y_train = tf.constant(y_train, shape=(y_train.shape[0], 1))
y_test = tf.constant(y_test, shape=(y_test.shape[0], 1))

# %%
# Adaptive Layer (no inner_structure)
# 341 params
adaptive_nn_model_no_inner = AdaptiveModel([
    AdaptiveLayer(5, structure=[], inner_out_activation=tf.nn.sigmoid, skip_w=0),
    AdaptiveLayer(5, structure=[], inner_out_activation=tf.nn.sigmoid, skip_w=0),
    AdaptiveLayer(1, structure=[], inner_out_activation=tf.nn.sigmoid, skip_w=0)
])

# %%
# Adaptive Layer (with inner_structure)
# 353 params
adaptive_nn_model_with_inner = AdaptiveModel([
    AdaptiveLayer(5, structure=[2, 1], inner_out_activation=tf.nn.sigmoid, skip_w=0.1),
    AdaptiveLayer(1, structure=[2, 1], inner_out_activation=tf.nn.sigmoid, skip_w=0.1)
])

# %%
# Adaptive Layer based on 1D Conv (no inner_structure)
# 386 params
adaptive_conv_nn_model_no_inner = AdaptiveModel([
    AdaptiveLayerConv(5, structure=[], split=1, skip_w=0, noise=0, inner_out_activation=tf.nn.sigmoid),
    AdaptiveLayerConv(4, structure=[], split=1, skip_w=0, noise=0, inner_out_activation=tf.nn.sigmoid),
    AdaptiveLayerConv(1, structure=[], split=1, skip_w=0, noise=0, inner_out_activation=tf.nn.sigmoid)
])

# %%
# Adaptive Layer based on 1D Conv (with inner_structure)
# 381 params
adaptive_conv_nn_model_with_inner = AdaptiveModel([
    AdaptiveLayerConv(5, structure=[2, 4], split=1, skip_w=0.1, noise=0, inner_out_activation=tf.nn.sigmoid),
    AdaptiveLayerConv(1, structure=[2, 4], split=1, skip_w=0.1, noise=0, inner_out_activation=tf.nn.sigmoid)
])

# %%
tmp = adaptive_nn_model_no_inner.predict(x_test)
tmp = adaptive_nn_model_with_inner.predict(x_test)
tmp = adaptive_conv_nn_model_no_inner.predict(x_test)
tmp = adaptive_conv_nn_model_with_inner.predict(x_test)
# Out:
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 1ms/step

# %%
def extract_weights(model, outter=True, conv=False):
    tmp = []
    for i in range(len(model.l)):
        if outter:
            tmp.append(model.l[i].outer_w.numpy())
        else:
            if not conv:
                tmp.append(model.l[i].inner_w[0].numpy())
            else:
                tmp.append(model.l[i].inner_w[0].weights[0].numpy())
    
    return tmp

# %%
adaptive_nn_model_with_inner.l[0].inner_w[0].numpy()
# Out:
# array([[[ 3.331327  ,  1.3756878 ]],
#
#        [[ 1.9870344 , -4.192154  ]],
#
#        [[ 2.187041  ,  0.1368651 ]],
#
#        [[-2.9338264 ,  3.8549056 ]],
#
#        [[ 0.28396088,  1.9528294 ]]], dtype=float32)

# %%
initial_outer_w_anm_no_inner = extract_weights(adaptive_nn_model_no_inner)
initial_outer_w_anm_with_inner = extract_weights(adaptive_nn_model_with_inner)
initial_inner_w_anm_with_inner = extract_weights(adaptive_nn_model_with_inner, outter=False)
initial_outer_w_acnm_no_inner = extract_weights(adaptive_conv_nn_model_no_inner)
initial_outer_w_acnm_with_inner = extract_weights(adaptive_conv_nn_model_with_inner)
initial_inner_w_acnm_with_inner = extract_weights(adaptive_conv_nn_model_with_inner, outter=False, conv=True)

# %%
adaptive_nn_model_no_inner.compile(optimizer=tf.optimizers.legacy.Adam(learning_rate=0.003), 
                       loss="binary_crossentropy", metrics=['accuracy'])

# %%
adaptive_nn_model_with_inner.compile(optimizer=tf.optimizers.legacy.Adam(learning_rate=0.003), 
                       loss="binary_crossentropy", metrics=['accuracy'])

# %%
adaptive_conv_nn_model_no_inner.compile(optimizer=tf.optimizers.legacy.Adam(learning_rate=0.003), 
                       loss="binary_crossentropy", metrics=['accuracy'])

# %%
adaptive_conv_nn_model_with_inner.compile(optimizer=tf.optimizers.legacy.Adam(learning_rate=0.003), 
                       loss="binary_crossentropy", metrics=['accuracy'])

# %%
EPOCHS = 10

# %%
adaptive_nn_model_no_inner.fit(x_train, y_train, epochs=EPOCHS)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6927 - accuracy: 0.5562
# Epoch 2/10
# 5/5 [==============================] - 0s 987us/step - loss: 0.6905 - accuracy: 0.5562
# Epoch 3/10
# 5/5 [==============================] - 0s 988us/step - loss: 0.6894 - accuracy: 0.5562
# Epoch 4/10
# 5/5 [==============================] - 0s 903us/step - loss: 0.6890 - accuracy: 0.5562
# Epoch 5/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6880 - accuracy: 0.5562
# Epoch 6/10
# 5/5 [==============================] - 0s 847us/step - loss: 0.6877 - accuracy: 0.5562
# Epoch 7/10
# 5/5 [==============================] - 0s 880us/step - loss: 0.6876 - accuracy: 0.5562
# Epoch 8/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6871 - accuracy: 0.5562
# Epoch 9/10
# 5/5 [==============================] - 0s 770us/step - loss: 0.6870 - accuracy: 0.5562
# Epoch 10/10
# 5/5 [==============================] - 0s 908us/step - loss: 0.6868 - accuracy: 0.5562

# %%
adaptive_nn_model_with_inner.fit(x_train, y_train, epochs=EPOCHS)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 0s 867us/step - loss: 0.6922 - accuracy: 0.5562
# Epoch 2/10
# 5/5 [==============================] - 0s 716us/step - loss: 0.6863 - accuracy: 0.5562
# Epoch 3/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6849 - accuracy: 0.5562
# Epoch 4/10
# 5/5 [==============================] - 0s 950us/step - loss: 0.6824 - accuracy: 0.5562
# Epoch 5/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6816 - accuracy: 0.5562
# Epoch 6/10
# 5/5 [==============================] - 0s 961us/step - loss: 0.6775 - accuracy: 0.5562
# Epoch 7/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6754 - accuracy: 0.5562
# Epoch 8/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6717 - accuracy: 0.5562
# Epoch 9/10
# 5/5 [==============================] - 0s 828us/step - loss: 0.6669 - accuracy: 0.5562
# Epoch 10/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6616 - accuracy: 0.5562

# %%
adaptive_conv_nn_model_no_inner.fit(x_train, y_train, epochs=EPOCHS)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 0s 897us/step - loss: 0.6935 - accuracy: 0.4313
# Epoch 2/10
# 5/5 [==============================] - 0s 977us/step - loss: 0.6921 - accuracy: 0.5562
# Epoch 3/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6912 - accuracy: 0.5562
# Epoch 4/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6908 - accuracy: 0.5562
# Epoch 5/10
# 5/5 [==============================] - 0s 973us/step - loss: 0.6899 - accuracy: 0.5562
# Epoch 6/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6895 - accuracy: 0.5562
# Epoch 7/10
# 5/5 [==============================] - 0s 915us/step - loss: 0.6892 - accuracy: 0.5562
# Epoch 8/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6886 - accuracy: 0.5562
# Epoch 9/10
# 5/5 [==============================] - 0s 944us/step - loss: 0.6883 - accuracy: 0.5562
# Epoch 10/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6880 - accuracy: 0.5562

# %%
adaptive_conv_nn_model_with_inner.fit(x_train, y_train, epochs=EPOCHS)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 0s 932us/step - loss: 0.6958 - accuracy: 0.4563
# Epoch 2/10
# 5/5 [==============================] - 0s 798us/step - loss: 0.6918 - accuracy: 0.5562
# Epoch 3/10
# 5/5 [==============================] - 0s 833us/step - loss: 0.6899 - accuracy: 0.5562
# Epoch 4/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6893 - accuracy: 0.5562
# Epoch 5/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6879 - accuracy: 0.5562
# Epoch 6/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6875 - accuracy: 0.5562
# Epoch 7/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6874 - accuracy: 0.5562
# Epoch 8/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6869 - accuracy: 0.5562
# Epoch 9/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6867 - accuracy: 0.5562
# Epoch 10/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6866 - accuracy: 0.5562

# %%
e10_outer_w_anm_no_inner = extract_weights(adaptive_nn_model_no_inner)
e10_outer_w_anm_with_inner = extract_weights(adaptive_nn_model_with_inner)
e10_inner_w_anm_with_inner = extract_weights(adaptive_nn_model_with_inner, outter=False)
e10_outer_w_acnm_no_inner = extract_weights(adaptive_conv_nn_model_no_inner)
e10_outer_w_acnm_with_inner = extract_weights(adaptive_conv_nn_model_with_inner)
e10_inner_w_acnm_with_inner = extract_weights(adaptive_conv_nn_model_with_inner, outter=False, conv=True)

# %%
print("10 - initial\nSUM:")
index = 0
print("outer_w_anm_no_inner", np.sum(np.abs(e10_outer_w_anm_no_inner[index] - initial_outer_w_anm_no_inner[index])))
print("outer_w_anm_with_inner", np.sum(np.abs(e10_outer_w_anm_with_inner[index] - initial_outer_w_anm_with_inner[index])))
print("inner_w_anm_with_inner", np.sum(np.abs(e10_inner_w_anm_with_inner[index] - initial_inner_w_anm_with_inner[index])))
print("outer_w_acnm_no_inner", np.sum(np.abs(e10_outer_w_acnm_no_inner[index] - initial_outer_w_acnm_no_inner[index])))
print("outer_w_acnm_with_inner", np.sum(np.abs(e10_outer_w_acnm_with_inner[index] - initial_outer_w_acnm_with_inner[index])))
print("inner_w_acnm_with_inner", np.sum(np.abs(e10_inner_w_acnm_with_inner[index] - initial_inner_w_acnm_with_inner[index])))
print("\nAVERAGE:")
print("outer_w_anm_no_inner", np.average(np.abs(e10_outer_w_anm_no_inner[index] - initial_outer_w_anm_no_inner[index])))
print("outer_w_anm_with_inner", np.average(np.abs(e10_outer_w_anm_with_inner[index] - initial_outer_w_anm_with_inner[index])))
print("inner_w_anm_with_inner", np.average(np.abs(e10_inner_w_anm_with_inner[index] - initial_inner_w_anm_with_inner[index])))
print("outer_w_acnm_no_inner", np.average(np.abs(e10_outer_w_acnm_no_inner[index] - initial_outer_w_acnm_no_inner[index])))
print("outer_w_acnm_with_inner", np.average(np.abs(e10_outer_w_acnm_with_inner[index] - initial_outer_w_acnm_with_inner[index])))
print("inner_w_acnm_with_inner", np.average(np.abs(e10_inner_w_acnm_with_inner[index] - initial_inner_w_acnm_with_inner[index])))
# Out:
# 10 - initial
# SUM:
# outer_w_anm_no_inner 20.19879
# outer_w_anm_with_inner 18.398155
# inner_w_anm_with_inner 0.46549246
# outer_w_acnm_no_inner 12.218704
# outer_w_acnm_with_inner 12.559346
# inner_w_acnm_with_inner 0.42807242
#
# AVERAGE:
# outer_w_anm_no_inner 0.067329295
# outer_w_anm_with_inner 0.061327185
# inner_w_anm_with_inner 0.046549246
# outer_w_acnm_no_inner 0.040729012
# outer_w_acnm_with_inner 0.04186449
# inner_w_acnm_with_inner 0.042807244

# %%
EPOCHS = 90

# %%
adaptive_nn_model_no_inner.fit(x_train, y_train, epochs=EPOCHS)
# Out:
# Epoch 1/90
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6869 - accuracy: 0.5562
# Epoch 2/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6865 - accuracy: 0.5562
# Epoch 3/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6865 - accuracy: 0.5562
# Epoch 4/90
# 5/5 [==============================] - 0s 992us/step - loss: 0.6865 - accuracy: 0.5562
# Epoch 5/90
# 5/5 [==============================] - 0s 955us/step - loss: 0.6866 - accuracy: 0.5562
# Epoch 6/90
# 5/5 [==============================] - 0s 937us/step - loss: 0.6862 - accuracy: 0.5562
# Epoch 7/90
# 5/5 [==============================] - 0s 783us/step - loss: 0.6862 - accuracy: 0.5562
# Epoch 8/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6861 - accuracy: 0.5562
# Epoch 9/90
# 5/5 [==============================] - 0s 792us/step - loss: 0.6860 - accuracy: 0.5562
# Epoch 10/90
# 5/5 [==============================] - 0s 857us/step - loss: 0.6859 - accuracy: 0.5562
# Epoch 11/90
# 5/5 [==============================] - 0s 821us/step - loss: 0.6858 - accuracy: 0.5562
# Epoch 12/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6856 - accuracy: 0.5562
# Epoch 13/90
# 5/5 [==============================] - 0s 777us/step - loss: 0.6857 - accuracy: 0.5562
# Epoch 14/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6853 - accuracy: 0.5562
# Epoch 15/90
# 5/5 [==============================] - 0s 749us/step - loss: 0.6852 - accuracy: 0.5562
# Epoch 16/90
# 5/5 [==============================] - 0s 774us/step - loss: 0.6849 - accuracy: 0.5562
# Epoch 17/90
# 5/5 [==============================] - 0s 774us/step - loss: 0.6847 - accuracy: 0.5562
# Epoch 18/90
# 5/5 [==============================] - 0s 764us/step - loss: 0.6846 - accuracy: 0.5562
# Epoch 19/90
# 5/5 [==============================] - 0s 732us/step - loss: 0.6842 - accuracy: 0.5562
# Epoch 20/90
# 5/5 [==============================] - 0s 832us/step - loss: 0.6840 - accuracy: 0.5562
# Epoch 21/90
# 5/5 [==============================] - 0s 877us/step - loss: 0.6837 - accuracy: 0.5562
# Epoch 22/90
# 5/5 [==============================] - 0s 782us/step - loss: 0.6833 - accuracy: 0.5562
# Epoch 23/90
# 5/5 [==============================] - 0s 786us/step - loss: 0.6833 - accuracy: 0.5562
# Epoch 24/90
# 5/5 [==============================] - 0s 756us/step - loss: 0.6826 - accuracy: 0.5562
# Epoch 25/90
# 5/5 [==============================] - 0s 801us/step - loss: 0.6823 - accuracy: 0.5562
# Epoch 26/90
# 5/5 [==============================] - 0s 742us/step - loss: 0.6819 - accuracy: 0.5562
# Epoch 27/90
# 5/5 [==============================] - 0s 933us/step - loss: 0.6812 - accuracy: 0.5562
# Epoch 28/90
# 5/5 [==============================] - 0s 759us/step - loss: 0.6810 - accuracy: 0.5562
# Epoch 29/90
# 5/5 [==============================] - 0s 711us/step - loss: 0.6806 - accuracy: 0.5562
# Epoch 30/90
# 5/5 [==============================] - 0s 732us/step - loss: 0.6797 - accuracy: 0.5562
# Epoch 31/90
# 5/5 [==============================] - 0s 861us/step - loss: 0.6789 - accuracy: 0.5562
# Epoch 32/90
# 5/5 [==============================] - 0s 708us/step - loss: 0.6784 - accuracy: 0.5562
# Epoch 33/90
# 5/5 [==============================] - 0s 727us/step - loss: 0.6775 - accuracy: 0.5562
# Epoch 34/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6767 - accuracy: 0.5562
# Epoch 35/90
# 5/5 [==============================] - 0s 731us/step - loss: 0.6757 - accuracy: 0.5562
# Epoch 36/90
# 5/5 [==============================] - 0s 720us/step - loss: 0.6747 - accuracy: 0.5562
# Epoch 37/90
# 5/5 [==============================] - 0s 872us/step - loss: 0.6737 - accuracy: 0.5562
# Epoch 38/90
# 5/5 [==============================] - 0s 771us/step - loss: 0.6725 - accuracy: 0.5562
# Epoch 39/90
# 5/5 [==============================] - 0s 931us/step - loss: 0.6713 - accuracy: 0.5562
# Epoch 40/90
# 5/5 [==============================] - 0s 823us/step - loss: 0.6700 - accuracy: 0.5562
# Epoch 41/90
# 5/5 [==============================] - 0s 802us/step - loss: 0.6685 - accuracy: 0.5562
# Epoch 42/90
# 5/5 [==============================] - 0s 710us/step - loss: 0.6671 - accuracy: 0.5562
# Epoch 43/90
# 5/5 [==============================] - 0s 797us/step - loss: 0.6656 - accuracy: 0.5562
# Epoch 44/90
# 5/5 [==============================] - 0s 956us/step - loss: 0.6638 - accuracy: 0.5562
# Epoch 45/90
# 5/5 [==============================] - 0s 844us/step - loss: 0.6617 - accuracy: 0.5562
# Epoch 46/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6603 - accuracy: 0.5562
# Epoch 47/90
# 5/5 [==============================] - 0s 754us/step - loss: 0.6584 - accuracy: 0.5562
# Epoch 48/90
# 5/5 [==============================] - 0s 732us/step - loss: 0.6557 - accuracy: 0.5562
# Epoch 49/90
# 5/5 [==============================] - 0s 973us/step - loss: 0.6537 - accuracy: 0.5562
# Epoch 50/90
# 5/5 [==============================] - 0s 966us/step - loss: 0.6513 - accuracy: 0.5562
# Epoch 51/90
# 5/5 [==============================] - 0s 745us/step - loss: 0.6490 - accuracy: 0.5562
# Epoch 52/90
# 5/5 [==============================] - 0s 868us/step - loss: 0.6465 - accuracy: 0.5562
# Epoch 53/90
# 5/5 [==============================] - 0s 854us/step - loss: 0.6441 - accuracy: 0.5562
# Epoch 54/90
# 5/5 [==============================] - 0s 773us/step - loss: 0.6412 - accuracy: 0.5562
# Epoch 55/90
# 5/5 [==============================] - 0s 878us/step - loss: 0.6384 - accuracy: 0.5562
# Epoch 56/90
# 5/5 [==============================] - 0s 872us/step - loss: 0.6356 - accuracy: 0.5562
# Epoch 57/90
# 5/5 [==============================] - 0s 809us/step - loss: 0.6327 - accuracy: 0.5625
# Epoch 58/90
# 5/5 [==============================] - 0s 965us/step - loss: 0.6299 - accuracy: 0.5688
# Epoch 59/90
# 5/5 [==============================] - 0s 806us/step - loss: 0.6265 - accuracy: 0.5813
# Epoch 60/90
# 5/5 [==============================] - 0s 942us/step - loss: 0.6231 - accuracy: 0.6000
# Epoch 61/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6201 - accuracy: 0.6562
# Epoch 62/90
# 5/5 [==============================] - 0s 776us/step - loss: 0.6162 - accuracy: 0.6875
# Epoch 63/90
# 5/5 [==============================] - 0s 747us/step - loss: 0.6129 - accuracy: 0.7000
# Epoch 64/90
# 5/5 [==============================] - 0s 830us/step - loss: 0.6096 - accuracy: 0.7000
# Epoch 65/90
# 5/5 [==============================] - 0s 886us/step - loss: 0.6065 - accuracy: 0.7000
# Epoch 66/90
# 5/5 [==============================] - 0s 784us/step - loss: 0.6025 - accuracy: 0.7000
# Epoch 67/90
# 5/5 [==============================] - 0s 807us/step - loss: 0.5992 - accuracy: 0.7000
# Epoch 68/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.5949 - accuracy: 0.7063
# Epoch 69/90
# 5/5 [==============================] - 0s 821us/step - loss: 0.5918 - accuracy: 0.7125
# Epoch 70/90
# 5/5 [==============================] - 0s 825us/step - loss: 0.5880 - accuracy: 0.7375
# Epoch 71/90
# 5/5 [==============================] - 0s 995us/step - loss: 0.5839 - accuracy: 0.7437
# Epoch 72/90
# 5/5 [==============================] - 0s 782us/step - loss: 0.5805 - accuracy: 0.7437
# Epoch 73/90
# 5/5 [==============================] - 0s 786us/step - loss: 0.5768 - accuracy: 0.7437
# Epoch 74/90
# 5/5 [==============================] - 0s 778us/step - loss: 0.5730 - accuracy: 0.7500
# Epoch 75/90
# 5/5 [==============================] - 0s 733us/step - loss: 0.5694 - accuracy: 0.7500
# Epoch 76/90
# 5/5 [==============================] - 0s 785us/step - loss: 0.5652 - accuracy: 0.7500
# Epoch 77/90
# 5/5 [==============================] - 0s 991us/step - loss: 0.5615 - accuracy: 0.7688
# Epoch 78/90
# 5/5 [==============================] - 0s 725us/step - loss: 0.5578 - accuracy: 0.7688
# Epoch 79/90
# 5/5 [==============================] - 0s 757us/step - loss: 0.5545 - accuracy: 0.7750
# Epoch 80/90
# 5/5 [==============================] - 0s 753us/step - loss: 0.5509 - accuracy: 0.7625
# Epoch 81/90
# 5/5 [==============================] - 0s 736us/step - loss: 0.5470 - accuracy: 0.7750
# Epoch 82/90
# 5/5 [==============================] - 0s 703us/step - loss: 0.5434 - accuracy: 0.7688
# Epoch 83/90
# 5/5 [==============================] - 0s 721us/step - loss: 0.5394 - accuracy: 0.7688
# Epoch 84/90
# 5/5 [==============================] - 0s 712us/step - loss: 0.5368 - accuracy: 0.7750
# Epoch 85/90
# 5/5 [==============================] - 0s 753us/step - loss: 0.5323 - accuracy: 0.7750
# Epoch 86/90
# 5/5 [==============================] - 0s 748us/step - loss: 0.5295 - accuracy: 0.7937
# Epoch 87/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.5263 - accuracy: 0.8000
# Epoch 88/90
# 5/5 [==============================] - 0s 746us/step - loss: 0.5223 - accuracy: 0.7875
# Epoch 89/90
# 5/5 [==============================] - 0s 769us/step - loss: 0.5187 - accuracy: 0.7937
# Epoch 90/90
# 5/5 [==============================] - 0s 904us/step - loss: 0.5148 - accuracy: 0.7937

# %%
adaptive_nn_model_with_inner.fit(x_train, y_train, epochs=EPOCHS)
# Out:
# Epoch 1/90
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6564 - accuracy: 0.5562
# Epoch 2/90
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6478 - accuracy: 0.5875
# Epoch 3/90
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6409 - accuracy: 0.6938
# Epoch 4/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6309 - accuracy: 0.6938
# Epoch 5/90
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6251 - accuracy: 0.7375
# Epoch 6/90
# 5/5 [==============================] - 0s 848us/step - loss: 0.6075 - accuracy: 0.7563
# Epoch 7/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.5978 - accuracy: 0.7312
# Epoch 8/90
# 5/5 [==============================] - 0s 910us/step - loss: 0.5834 - accuracy: 0.7812
# Epoch 9/90
# 5/5 [==============================] - 0s 859us/step - loss: 0.5671 - accuracy: 0.8125
# Epoch 10/90
# 5/5 [==============================] - 0s 986us/step - loss: 0.5510 - accuracy: 0.7750
# Epoch 11/90
# 5/5 [==============================] - 0s 787us/step - loss: 0.5381 - accuracy: 0.8000
# Epoch 12/90
# 5/5 [==============================] - 0s 812us/step - loss: 0.5174 - accuracy: 0.8250
# Epoch 13/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.5128 - accuracy: 0.7812
# Epoch 14/90
# 5/5 [==============================] - 0s 785us/step - loss: 0.4964 - accuracy: 0.7937
# Epoch 15/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.4763 - accuracy: 0.8250
# Epoch 16/90
# 5/5 [==============================] - 0s 804us/step - loss: 0.4584 - accuracy: 0.8125
# Epoch 17/90
# 5/5 [==============================] - 0s 781us/step - loss: 0.4444 - accuracy: 0.8250
# Epoch 18/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.4282 - accuracy: 0.8500
# Epoch 19/90
# 5/5 [==============================] - 0s 823us/step - loss: 0.4153 - accuracy: 0.8375
# Epoch 20/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.4040 - accuracy: 0.8375
# Epoch 21/90
# 5/5 [==============================] - 0s 801us/step - loss: 0.3928 - accuracy: 0.8750
# Epoch 22/90
# 5/5 [==============================] - 0s 841us/step - loss: 0.3826 - accuracy: 0.8562
# Epoch 23/90
# 5/5 [==============================] - 0s 989us/step - loss: 0.3743 - accuracy: 0.8562
# Epoch 24/90
# 5/5 [==============================] - 0s 789us/step - loss: 0.3704 - accuracy: 0.8625
# Epoch 25/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.3665 - accuracy: 0.8625
# Epoch 26/90
# 5/5 [==============================] - 0s 878us/step - loss: 0.3513 - accuracy: 0.8750
# Epoch 27/90
# 5/5 [==============================] - 0s 844us/step - loss: 0.3455 - accuracy: 0.8687
# Epoch 28/90
# 5/5 [==============================] - 0s 787us/step - loss: 0.3356 - accuracy: 0.8625
# Epoch 29/90
# 5/5 [==============================] - 0s 842us/step - loss: 0.3350 - accuracy: 0.8625
# Epoch 30/90
# 5/5 [==============================] - 0s 832us/step - loss: 0.3465 - accuracy: 0.8625
# Epoch 31/90
# 5/5 [==============================] - 0s 761us/step - loss: 0.3257 - accuracy: 0.8687
# Epoch 32/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.3152 - accuracy: 0.9062
# Epoch 33/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.3092 - accuracy: 0.9125
# Epoch 34/90
# 5/5 [==============================] - 0s 821us/step - loss: 0.3116 - accuracy: 0.8938
# Epoch 35/90
# 5/5 [==============================] - 0s 782us/step - loss: 0.3117 - accuracy: 0.8938
# Epoch 36/90
# 5/5 [==============================] - 0s 866us/step - loss: 0.2975 - accuracy: 0.8875
# Epoch 37/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.2963 - accuracy: 0.9000
# Epoch 38/90
# 5/5 [==============================] - 0s 798us/step - loss: 0.2906 - accuracy: 0.9187
# Epoch 39/90
# 5/5 [==============================] - 0s 785us/step - loss: 0.2804 - accuracy: 0.9187
# Epoch 40/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.2797 - accuracy: 0.9250
# Epoch 41/90
# 5/5 [==============================] - 0s 788us/step - loss: 0.2712 - accuracy: 0.9312
# Epoch 42/90
# 5/5 [==============================] - 0s 767us/step - loss: 0.2722 - accuracy: 0.9250
# Epoch 43/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.2635 - accuracy: 0.9250
# Epoch 44/90
# 5/5 [==============================] - 0s 830us/step - loss: 0.2783 - accuracy: 0.8813
# Epoch 45/90
# 5/5 [==============================] - 0s 776us/step - loss: 0.3057 - accuracy: 0.8687
# Epoch 46/90
# 5/5 [==============================] - 0s 838us/step - loss: 0.2635 - accuracy: 0.8875
# Epoch 47/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.2499 - accuracy: 0.9312
# Epoch 48/90
# 5/5 [==============================] - 0s 779us/step - loss: 0.2586 - accuracy: 0.9125
# Epoch 49/90
# 5/5 [==============================] - 0s 802us/step - loss: 0.2524 - accuracy: 0.9187
# Epoch 50/90
# 5/5 [==============================] - 0s 776us/step - loss: 0.2408 - accuracy: 0.9250
# Epoch 51/90
# 5/5 [==============================] - 0s 886us/step - loss: 0.2399 - accuracy: 0.9312
# Epoch 52/90
# 5/5 [==============================] - 0s 792us/step - loss: 0.2363 - accuracy: 0.9250
# Epoch 53/90
# 5/5 [==============================] - 0s 760us/step - loss: 0.2342 - accuracy: 0.9250
# Epoch 54/90
# 5/5 [==============================] - 0s 765us/step - loss: 0.2341 - accuracy: 0.9312
# Epoch 55/90
# 5/5 [==============================] - 0s 832us/step - loss: 0.2264 - accuracy: 0.9250
# Epoch 56/90
# 5/5 [==============================] - 0s 759us/step - loss: 0.2238 - accuracy: 0.9250
# Epoch 57/90
# 5/5 [==============================] - 0s 906us/step - loss: 0.2323 - accuracy: 0.9187
# Epoch 58/90
# 5/5 [==============================] - 0s 849us/step - loss: 0.2159 - accuracy: 0.9312
# Epoch 59/90
# 5/5 [==============================] - 0s 749us/step - loss: 0.2149 - accuracy: 0.9250
# Epoch 60/90
# 5/5 [==============================] - 0s 777us/step - loss: 0.2191 - accuracy: 0.9250
# Epoch 61/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.2148 - accuracy: 0.9250
# Epoch 62/90
# 5/5 [==============================] - 0s 813us/step - loss: 0.2044 - accuracy: 0.9250
# Epoch 63/90
# 5/5 [==============================] - 0s 762us/step - loss: 0.2012 - accuracy: 0.9250
# Epoch 64/90
# 5/5 [==============================] - 0s 788us/step - loss: 0.1992 - accuracy: 0.9250
# Epoch 65/90
# 5/5 [==============================] - 0s 746us/step - loss: 0.1978 - accuracy: 0.9250
# Epoch 66/90
# 5/5 [==============================] - 0s 761us/step - loss: 0.2118 - accuracy: 0.9125
# Epoch 67/90
# 5/5 [==============================] - 0s 785us/step - loss: 0.1985 - accuracy: 0.9312
# Epoch 68/90
# 5/5 [==============================] - 0s 785us/step - loss: 0.1974 - accuracy: 0.9187
# Epoch 69/90
# 5/5 [==============================] - 0s 732us/step - loss: 0.1879 - accuracy: 0.9375
# Epoch 70/90
# 5/5 [==============================] - 0s 734us/step - loss: 0.1908 - accuracy: 0.9250
# Epoch 71/90
# 5/5 [==============================] - 0s 755us/step - loss: 0.1980 - accuracy: 0.9375
# Epoch 72/90
# 5/5 [==============================] - 0s 770us/step - loss: 0.1822 - accuracy: 0.9438
# Epoch 73/90
# 5/5 [==============================] - 0s 768us/step - loss: 0.1765 - accuracy: 0.9438
# Epoch 74/90
# 5/5 [==============================] - 0s 777us/step - loss: 0.1702 - accuracy: 0.9438
# Epoch 75/90
# 5/5 [==============================] - 0s 809us/step - loss: 0.1676 - accuracy: 0.9500
# Epoch 76/90
# 5/5 [==============================] - 0s 775us/step - loss: 0.1771 - accuracy: 0.9438
# Epoch 77/90
# 5/5 [==============================] - 0s 790us/step - loss: 0.1598 - accuracy: 0.9563
# Epoch 78/90
# 5/5 [==============================] - 0s 749us/step - loss: 0.1599 - accuracy: 0.9625
# Epoch 79/90
# 5/5 [==============================] - 0s 867us/step - loss: 0.1557 - accuracy: 0.9625
# Epoch 80/90
# 5/5 [==============================] - 0s 792us/step - loss: 0.1640 - accuracy: 0.9500
# Epoch 81/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.1716 - accuracy: 0.9438
# Epoch 82/90
# 5/5 [==============================] - 0s 769us/step - loss: 0.1633 - accuracy: 0.9500
# Epoch 83/90
# 5/5 [==============================] - 0s 804us/step - loss: 0.1692 - accuracy: 0.9438
# Epoch 84/90
# 5/5 [==============================] - 0s 804us/step - loss: 0.1953 - accuracy: 0.9250
# Epoch 85/90
# 5/5 [==============================] - 0s 760us/step - loss: 0.1927 - accuracy: 0.9312
# Epoch 86/90
# 5/5 [==============================] - 0s 773us/step - loss: 0.1579 - accuracy: 0.9500
# Epoch 87/90
# 5/5 [==============================] - 0s 773us/step - loss: 0.1600 - accuracy: 0.9563
# Epoch 88/90
# 5/5 [==============================] - 0s 987us/step - loss: 0.1757 - accuracy: 0.9250
# Epoch 89/90
# 5/5 [==============================] - 0s 797us/step - loss: 0.1992 - accuracy: 0.9187
# Epoch 90/90
# 5/5 [==============================] - 0s 750us/step - loss: 0.1479 - accuracy: 0.9688

# %%
adaptive_conv_nn_model_no_inner.fit(x_train, y_train, epochs=EPOCHS)
# Out:
# Epoch 1/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6879 - accuracy: 0.5562
# Epoch 2/90
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6873 - accuracy: 0.5562
# Epoch 3/90
# 5/5 [==============================] - 0s 894us/step - loss: 0.6872 - accuracy: 0.5562
# Epoch 4/90
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6871 - accuracy: 0.5562
# Epoch 5/90
# 5/5 [==============================] - 0s 892us/step - loss: 0.6869 - accuracy: 0.5562
# Epoch 6/90
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6866 - accuracy: 0.5562
# Epoch 7/90
# 5/5 [==============================] - 0s 877us/step - loss: 0.6866 - accuracy: 0.5562
# Epoch 8/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6863 - accuracy: 0.5562
# Epoch 9/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6861 - accuracy: 0.5562
# Epoch 10/90
# 5/5 [==============================] - 0s 892us/step - loss: 0.6858 - accuracy: 0.5562
# Epoch 11/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6855 - accuracy: 0.5562
# Epoch 12/90
# 5/5 [==============================] - 0s 843us/step - loss: 0.6851 - accuracy: 0.5562
# Epoch 13/90
# 5/5 [==============================] - 0s 963us/step - loss: 0.6850 - accuracy: 0.5562
# Epoch 14/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6840 - accuracy: 0.5562
# Epoch 15/90
# 5/5 [==============================] - 0s 902us/step - loss: 0.6834 - accuracy: 0.5562
# Epoch 16/90
# 5/5 [==============================] - 0s 894us/step - loss: 0.6825 - accuracy: 0.5562
# Epoch 17/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6816 - accuracy: 0.5562
# Epoch 18/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6805 - accuracy: 0.5562
# Epoch 19/90
# 5/5 [==============================] - 0s 876us/step - loss: 0.6789 - accuracy: 0.5562
# Epoch 20/90
# 5/5 [==============================] - 0s 890us/step - loss: 0.6775 - accuracy: 0.5562
# Epoch 21/90
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6754 - accuracy: 0.5562
# Epoch 22/90
# 5/5 [==============================] - 0s 862us/step - loss: 0.6729 - accuracy: 0.5562
# Epoch 23/90
# 5/5 [==============================] - 0s 858us/step - loss: 0.6710 - accuracy: 0.5562
# Epoch 24/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6666 - accuracy: 0.5562
# Epoch 25/90
# 5/5 [==============================] - 0s 871us/step - loss: 0.6630 - accuracy: 0.5562
# Epoch 26/90
# 5/5 [==============================] - 0s 998us/step - loss: 0.6581 - accuracy: 0.5562
# Epoch 27/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6530 - accuracy: 0.5562
# Epoch 28/90
# 5/5 [==============================] - 0s 969us/step - loss: 0.6470 - accuracy: 0.5562
# Epoch 29/90
# 5/5 [==============================] - 0s 832us/step - loss: 0.6406 - accuracy: 0.5562
# Epoch 30/90
# 5/5 [==============================] - 0s 892us/step - loss: 0.6333 - accuracy: 0.5562
# Epoch 31/90
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6229 - accuracy: 0.5562
# Epoch 32/90
# 5/5 [==============================] - 0s 955us/step - loss: 0.6143 - accuracy: 0.5562
# Epoch 33/90
# 5/5 [==============================] - 0s 927us/step - loss: 0.6062 - accuracy: 0.5562
# Epoch 34/90
# 5/5 [==============================] - 0s 874us/step - loss: 0.5917 - accuracy: 0.5562
# Epoch 35/90
# 5/5 [==============================] - 0s 862us/step - loss: 0.5805 - accuracy: 0.5562
# Epoch 36/90
# 5/5 [==============================] - 0s 893us/step - loss: 0.5687 - accuracy: 0.5562
# Epoch 37/90
# 5/5 [==============================] - 0s 929us/step - loss: 0.5578 - accuracy: 0.5562
# Epoch 38/90
# 5/5 [==============================] - 0s 854us/step - loss: 0.5451 - accuracy: 0.6812
# Epoch 39/90
# 5/5 [==============================] - 0s 916us/step - loss: 0.5377 - accuracy: 0.7875
# Epoch 40/90
# 5/5 [==============================] - 0s 843us/step - loss: 0.5173 - accuracy: 0.8062
# Epoch 41/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.5090 - accuracy: 0.7937
# Epoch 42/90
# 5/5 [==============================] - 0s 872us/step - loss: 0.4974 - accuracy: 0.8375
# Epoch 43/90
# 5/5 [==============================] - 0s 842us/step - loss: 0.4858 - accuracy: 0.8000
# Epoch 44/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.4890 - accuracy: 0.8500
# Epoch 45/90
# 5/5 [==============================] - 0s 909us/step - loss: 0.4638 - accuracy: 0.8438
# Epoch 46/90
# 5/5 [==============================] - 0s 871us/step - loss: 0.4544 - accuracy: 0.8562
# Epoch 47/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.4521 - accuracy: 0.8813
# Epoch 48/90
# 5/5 [==============================] - 0s 914us/step - loss: 0.4374 - accuracy: 0.8562
# Epoch 49/90
# 5/5 [==============================] - 0s 933us/step - loss: 0.4320 - accuracy: 0.8813
# Epoch 50/90
# 5/5 [==============================] - 0s 902us/step - loss: 0.4205 - accuracy: 0.8687
# Epoch 51/90
# 5/5 [==============================] - 0s 841us/step - loss: 0.4107 - accuracy: 0.8813
# Epoch 52/90
# 5/5 [==============================] - 0s 897us/step - loss: 0.4105 - accuracy: 0.8875
# Epoch 53/90
# 5/5 [==============================] - 0s 905us/step - loss: 0.4120 - accuracy: 0.8562
# Epoch 54/90
# 5/5 [==============================] - 0s 831us/step - loss: 0.4066 - accuracy: 0.8813
# Epoch 55/90
# 5/5 [==============================] - 0s 850us/step - loss: 0.4068 - accuracy: 0.8500
# Epoch 56/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.3964 - accuracy: 0.8875
# Epoch 57/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.3789 - accuracy: 0.8813
# Epoch 58/90
# 5/5 [==============================] - 0s 923us/step - loss: 0.3805 - accuracy: 0.8625
# Epoch 59/90
# 5/5 [==============================] - 0s 971us/step - loss: 0.3859 - accuracy: 0.8813
# Epoch 60/90
# 5/5 [==============================] - 0s 925us/step - loss: 0.3693 - accuracy: 0.8875
# Epoch 61/90
# 5/5 [==============================] - 0s 965us/step - loss: 0.3812 - accuracy: 0.8687
# Epoch 62/90
# 5/5 [==============================] - 0s 891us/step - loss: 0.3585 - accuracy: 0.9000
# Epoch 63/90
# 5/5 [==============================] - 0s 878us/step - loss: 0.3578 - accuracy: 0.8813
# Epoch 64/90
# 5/5 [==============================] - 0s 943us/step - loss: 0.3552 - accuracy: 0.9000
# Epoch 65/90
# 5/5 [==============================] - 0s 849us/step - loss: 0.3476 - accuracy: 0.9000
# Epoch 66/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.3436 - accuracy: 0.9000
# Epoch 67/90
# 5/5 [==============================] - 0s 832us/step - loss: 0.3415 - accuracy: 0.9000
# Epoch 68/90
# 5/5 [==============================] - 0s 803us/step - loss: 0.3386 - accuracy: 0.9000
# Epoch 69/90
# 5/5 [==============================] - 0s 825us/step - loss: 0.3397 - accuracy: 0.8938
# Epoch 70/90
# 5/5 [==============================] - 0s 811us/step - loss: 0.3393 - accuracy: 0.8938
# Epoch 71/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.3324 - accuracy: 0.9000
# Epoch 72/90
# 5/5 [==============================] - 0s 853us/step - loss: 0.3270 - accuracy: 0.8938
# Epoch 73/90
# 5/5 [==============================] - 0s 796us/step - loss: 0.3343 - accuracy: 0.9000
# Epoch 74/90
# 5/5 [==============================] - 0s 821us/step - loss: 0.3235 - accuracy: 0.9000
# Epoch 75/90
# 5/5 [==============================] - 0s 804us/step - loss: 0.3332 - accuracy: 0.8875
# Epoch 76/90
# 5/5 [==============================] - 0s 977us/step - loss: 0.3271 - accuracy: 0.9062
# Epoch 77/90
# 5/5 [==============================] - 0s 822us/step - loss: 0.3266 - accuracy: 0.8875
# Epoch 78/90
# 5/5 [==============================] - 0s 813us/step - loss: 0.3213 - accuracy: 0.9000
# Epoch 79/90
# 5/5 [==============================] - 0s 812us/step - loss: 0.3144 - accuracy: 0.9062
# Epoch 80/90
# 5/5 [==============================] - 0s 819us/step - loss: 0.3137 - accuracy: 0.9062
# Epoch 81/90
# 5/5 [==============================] - 0s 812us/step - loss: 0.3130 - accuracy: 0.9000
# Epoch 82/90
# 5/5 [==============================] - 0s 816us/step - loss: 0.3101 - accuracy: 0.9062
# Epoch 83/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.3060 - accuracy: 0.9062
# Epoch 84/90
# 5/5 [==============================] - 0s 844us/step - loss: 0.3116 - accuracy: 0.9000
# Epoch 85/90
# 5/5 [==============================] - 0s 818us/step - loss: 0.3189 - accuracy: 0.9000
# Epoch 86/90
# 5/5 [==============================] - 0s 788us/step - loss: 0.3059 - accuracy: 0.9000
# Epoch 87/90
# 5/5 [==============================] - 0s 783us/step - loss: 0.2965 - accuracy: 0.9125
# Epoch 88/90
# 5/5 [==============================] - 0s 873us/step - loss: 0.2991 - accuracy: 0.9125
# Epoch 89/90
# 5/5 [==============================] - 0s 793us/step - loss: 0.3151 - accuracy: 0.9000
# Epoch 90/90
# 5/5 [==============================] - 0s 816us/step - loss: 0.2954 - accuracy: 0.9125

# %%
adaptive_conv_nn_model_with_inner.fit(x_train, y_train, epochs=EPOCHS)
# Out:
# Epoch 1/90
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6865 - accuracy: 0.5562
# Epoch 2/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6860 - accuracy: 0.5562
# Epoch 3/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6858 - accuracy: 0.5562
# Epoch 4/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6852 - accuracy: 0.5562
# Epoch 5/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6849 - accuracy: 0.5562
# Epoch 6/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6832 - accuracy: 0.5562
# Epoch 7/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6818 - accuracy: 0.5562
# Epoch 8/90
# 5/5 [==============================] - 0s 929us/step - loss: 0.6792 - accuracy: 0.5562
# Epoch 9/90
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6752 - accuracy: 0.5562
# Epoch 10/90
# 5/5 [==============================] - 0s 928us/step - loss: 0.6687 - accuracy: 0.5562
# Epoch 11/90
# 5/5 [==============================] - 0s 905us/step - loss: 0.6603 - accuracy: 0.5562
# Epoch 12/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6462 - accuracy: 0.5813
# Epoch 13/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6299 - accuracy: 0.7250
# Epoch 14/90
# 5/5 [==============================] - 0s 931us/step - loss: 0.6111 - accuracy: 0.7812
# Epoch 15/90
# 5/5 [==============================] - 0s 946us/step - loss: 0.5847 - accuracy: 0.8000
# Epoch 16/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.5498 - accuracy: 0.8062
# Epoch 17/90
# 5/5 [==============================] - 0s 863us/step - loss: 0.5320 - accuracy: 0.8062
# Epoch 18/90
# 5/5 [==============================] - 0s 904us/step - loss: 0.5074 - accuracy: 0.7937
# Epoch 19/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.4662 - accuracy: 0.8687
# Epoch 20/90
# 5/5 [==============================] - 0s 940us/step - loss: 0.4549 - accuracy: 0.8188
# Epoch 21/90
# 5/5 [==============================] - 0s 917us/step - loss: 0.4291 - accuracy: 0.8687
# Epoch 22/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.4469 - accuracy: 0.8000
# Epoch 23/90
# 5/5 [==============================] - 0s 893us/step - loss: 0.4319 - accuracy: 0.8313
# Epoch 24/90
# 5/5 [==============================] - 0s 930us/step - loss: 0.4143 - accuracy: 0.8375
# Epoch 25/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.3899 - accuracy: 0.8500
# Epoch 26/90
# 5/5 [==============================] - 0s 879us/step - loss: 0.3774 - accuracy: 0.8500
# Epoch 27/90
# 5/5 [==============================] - 0s 969us/step - loss: 0.3644 - accuracy: 0.8750
# Epoch 28/90
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3557 - accuracy: 0.8625
# Epoch 29/90
# 5/5 [==============================] - 0s 982us/step - loss: 0.3480 - accuracy: 0.8750
# Epoch 30/90
# 5/5 [==============================] - 0s 948us/step - loss: 0.3457 - accuracy: 0.8750
# Epoch 31/90
# 5/5 [==============================] - 0s 906us/step - loss: 0.3204 - accuracy: 0.8875
# Epoch 32/90
# 5/5 [==============================] - 0s 958us/step - loss: 0.3091 - accuracy: 0.9000
# Epoch 33/90
# 5/5 [==============================] - 0s 914us/step - loss: 0.2958 - accuracy: 0.9125
# Epoch 34/90
# 5/5 [==============================] - 0s 928us/step - loss: 0.2886 - accuracy: 0.9250
# Epoch 35/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.2839 - accuracy: 0.9187
# Epoch 36/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.3427 - accuracy: 0.8687
# Epoch 37/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.3053 - accuracy: 0.8938
# Epoch 38/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.3062 - accuracy: 0.8813
# Epoch 39/90
# 5/5 [==============================] - 0s 904us/step - loss: 0.3696 - accuracy: 0.8562
# Epoch 40/90
# 5/5 [==============================] - 0s 950us/step - loss: 0.3491 - accuracy: 0.8500
# Epoch 41/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.3099 - accuracy: 0.9062
# Epoch 42/90
# 5/5 [==============================] - 0s 891us/step - loss: 0.2677 - accuracy: 0.9375
# Epoch 43/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.2637 - accuracy: 0.9312
# Epoch 44/90
# 5/5 [==============================] - 0s 902us/step - loss: 0.2589 - accuracy: 0.9250
# Epoch 45/90
# 5/5 [==============================] - 0s 864us/step - loss: 0.2633 - accuracy: 0.9250
# Epoch 46/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.2617 - accuracy: 0.9250
# Epoch 47/90
# 5/5 [==============================] - 0s 951us/step - loss: 0.2542 - accuracy: 0.9312
# Epoch 48/90
# 5/5 [==============================] - 0s 929us/step - loss: 0.2463 - accuracy: 0.9312
# Epoch 49/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.2508 - accuracy: 0.9250
# Epoch 50/90
# 5/5 [==============================] - 0s 914us/step - loss: 0.2451 - accuracy: 0.9375
# Epoch 51/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.2442 - accuracy: 0.9250
# Epoch 52/90
# 5/5 [==============================] - 0s 883us/step - loss: 0.2438 - accuracy: 0.9312
# Epoch 53/90
# 5/5 [==============================] - 0s 905us/step - loss: 0.2367 - accuracy: 0.9375
# Epoch 54/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.2504 - accuracy: 0.9312
# Epoch 55/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.2352 - accuracy: 0.9438
# Epoch 56/90
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2276 - accuracy: 0.9438
# Epoch 57/90
# 5/5 [==============================] - 0s 885us/step - loss: 0.2265 - accuracy: 0.9375
# Epoch 58/90
# 5/5 [==============================] - 0s 917us/step - loss: 0.2210 - accuracy: 0.9438
# Epoch 59/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.2221 - accuracy: 0.9438
# Epoch 60/90
# 5/5 [==============================] - 0s 891us/step - loss: 0.2393 - accuracy: 0.9250
# Epoch 61/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.2727 - accuracy: 0.9062
# Epoch 62/90
# 5/5 [==============================] - 0s 930us/step - loss: 0.2946 - accuracy: 0.9000
# Epoch 63/90
# 5/5 [==============================] - 0s 890us/step - loss: 0.2315 - accuracy: 0.9250
# Epoch 64/90
# 5/5 [==============================] - 0s 999us/step - loss: 0.2392 - accuracy: 0.9312
# Epoch 65/90
# 5/5 [==============================] - 0s 912us/step - loss: 0.2592 - accuracy: 0.9062
# Epoch 66/90
# 5/5 [==============================] - 0s 964us/step - loss: 0.2564 - accuracy: 0.9187
# Epoch 67/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.2211 - accuracy: 0.9438
# Epoch 68/90
# 5/5 [==============================] - 0s 889us/step - loss: 0.2404 - accuracy: 0.9250
# Epoch 69/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.2063 - accuracy: 0.9438
# Epoch 70/90
# 5/5 [==============================] - 0s 893us/step - loss: 0.2103 - accuracy: 0.9375
# Epoch 71/90
# 5/5 [==============================] - 0s 930us/step - loss: 0.2056 - accuracy: 0.9500
# Epoch 72/90
# 5/5 [==============================] - 0s 965us/step - loss: 0.1984 - accuracy: 0.9500
# Epoch 73/90
# 5/5 [==============================] - 0s 896us/step - loss: 0.1933 - accuracy: 0.9563
# Epoch 74/90
# 5/5 [==============================] - 0s 915us/step - loss: 0.1945 - accuracy: 0.9563
# Epoch 75/90
# 5/5 [==============================] - 0s 886us/step - loss: 0.1925 - accuracy: 0.9500
# Epoch 76/90
# 5/5 [==============================] - 0s 885us/step - loss: 0.1880 - accuracy: 0.9563
# Epoch 77/90
# 5/5 [==============================] - 0s 948us/step - loss: 0.1911 - accuracy: 0.9500
# Epoch 78/90
# 5/5 [==============================] - 0s 943us/step - loss: 0.1876 - accuracy: 0.9563
# Epoch 79/90
# 5/5 [==============================] - 0s 908us/step - loss: 0.1868 - accuracy: 0.9563
# Epoch 80/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.1851 - accuracy: 0.9563
# Epoch 81/90
# 5/5 [==============================] - 0s 889us/step - loss: 0.1845 - accuracy: 0.9563
# Epoch 82/90
# 5/5 [==============================] - 0s 894us/step - loss: 0.1838 - accuracy: 0.9563
# Epoch 83/90
# 5/5 [==============================] - 0s 1ms/step - loss: 0.1846 - accuracy: 0.9563
# Epoch 84/90
# 5/5 [==============================] - 0s 888us/step - loss: 0.1836 - accuracy: 0.9563
# Epoch 85/90
# 5/5 [==============================] - 0s 992us/step - loss: 0.1975 - accuracy: 0.9500
# Epoch 86/90
# 5/5 [==============================] - 0s 929us/step - loss: 0.1837 - accuracy: 0.9500
# Epoch 87/90
# 5/5 [==============================] - 0s 871us/step - loss: 0.1792 - accuracy: 0.9563
# Epoch 88/90
# 5/5 [==============================] - 0s 960us/step - loss: 0.2004 - accuracy: 0.9438
# Epoch 89/90
# 5/5 [==============================] - 0s 940us/step - loss: 0.2008 - accuracy: 0.9438
# Epoch 90/90
# 5/5 [==============================] - 0s 900us/step - loss: 0.2228 - accuracy: 0.9187

# %%
e100_outer_w_anm_no_inner = extract_weights(adaptive_nn_model_no_inner)
e100_outer_w_anm_with_inner = extract_weights(adaptive_nn_model_with_inner)
e100_inner_w_anm_with_inner = extract_weights(adaptive_nn_model_with_inner, outter=False)
e100_outer_w_acnm_no_inner = extract_weights(adaptive_conv_nn_model_no_inner)
e100_outer_w_acnm_with_inner = extract_weights(adaptive_conv_nn_model_with_inner)
e100_inner_w_acnm_with_inner = extract_weights(adaptive_conv_nn_model_with_inner, outter=False, conv=True)

# %%
print("100 - initial\nSUM:")
index = 0
print("outer_w_anm_no_inner", np.sum(np.abs(e100_outer_w_anm_no_inner[index] - initial_outer_w_anm_no_inner[index])))
print("outer_w_anm_with_inner", np.sum(np.abs(e100_outer_w_anm_with_inner[index] - initial_outer_w_anm_with_inner[index])))
print("inner_w_anm_with_inner", np.sum(np.abs(e100_inner_w_anm_with_inner[index] - initial_inner_w_anm_with_inner[index])))
print("outer_w_acnm_no_inner", np.sum(np.abs(e100_outer_w_acnm_no_inner[index] - initial_outer_w_acnm_no_inner[index])))
print("outer_w_acnm_with_inner", np.sum(np.abs(e100_outer_w_acnm_with_inner[index] - initial_outer_w_acnm_with_inner[index])))
print("inner_w_acnm_with_inner", np.sum(np.abs(e100_inner_w_acnm_with_inner[index] - initial_inner_w_acnm_with_inner[index])))
print("\nAVERAGE:")
print("outer_w_anm_no_inner", np.average(np.abs(e100_outer_w_anm_no_inner[index] - initial_outer_w_anm_no_inner[index])))
print("outer_w_anm_with_inner", np.average(np.abs(e100_outer_w_anm_with_inner[index] - initial_outer_w_anm_with_inner[index])))
print("inner_w_anm_with_inner", np.average(np.abs(e100_inner_w_anm_with_inner[index] - initial_inner_w_anm_with_inner[index])))
print("outer_w_acnm_no_inner", np.average(np.abs(e100_outer_w_acnm_no_inner[index] - initial_outer_w_acnm_no_inner[index])))
print("outer_w_acnm_with_inner", np.average(np.abs(e100_outer_w_acnm_with_inner[index] - initial_outer_w_acnm_with_inner[index])))
print("inner_w_acnm_with_inner", np.average(np.abs(e100_inner_w_acnm_with_inner[index] - initial_inner_w_acnm_with_inner[index])))
# Out:
# 100 - initial
# SUM:
# outer_w_anm_no_inner 218.1046
# outer_w_anm_with_inner 69.165344
# inner_w_anm_with_inner 8.947897
# outer_w_acnm_no_inner 100.35298
# outer_w_acnm_with_inner 49.980484
# inner_w_acnm_with_inner 4.4160023
#
# AVERAGE:
# outer_w_anm_no_inner 0.7270153
# outer_w_anm_with_inner 0.23055115
# inner_w_anm_with_inner 0.8947897
# outer_w_acnm_no_inner 0.33450994
# outer_w_acnm_with_inner 0.16660161
# inner_w_acnm_with_inner 0.44160023

# %%
fig = plt.figure(figsize=(18, 10))
ax = fig.add_subplot()

plt.title("Relative change between 10 and 100 epochs of training", fontsize="xx-large")

x = ['outer_w_anm_no_inner', 'outer_w_anm_with_inner', 'inner_w_anm_with_inner',
     'outer_w_acnm_no_inner', 'outer_w_acnm_with_inner', 'inner_w_acnm_with_inner']

y = [np.sum(np.abs(e100_outer_w_anm_no_inner[index] - initial_outer_w_anm_no_inner[index]))/np.sum(np.abs(e10_outer_w_anm_no_inner[index] - initial_outer_w_anm_no_inner[index])),
      np.sum(np.abs(e100_outer_w_anm_with_inner[index] - initial_outer_w_anm_with_inner[index]))/np.sum(np.abs(e10_outer_w_anm_with_inner[index] - initial_outer_w_anm_with_inner[index])),
      np.sum(np.abs(e100_inner_w_anm_with_inner[index] - initial_inner_w_anm_with_inner[index]))/np.sum(np.abs(e10_inner_w_anm_with_inner[index] - initial_inner_w_anm_with_inner[index])),
      np.sum(np.abs(e100_outer_w_acnm_no_inner[index] - initial_outer_w_acnm_no_inner[index]))/np.sum(np.abs(e10_outer_w_acnm_no_inner[index] - initial_outer_w_acnm_no_inner[index])),
      np.sum(np.abs(e100_outer_w_acnm_with_inner[index] - initial_outer_w_acnm_with_inner[index]))/np.sum(np.abs(e10_outer_w_acnm_with_inner[index] - initial_outer_w_acnm_with_inner[index])),
      np.sum(np.abs(e100_inner_w_acnm_with_inner[index] - initial_inner_w_acnm_with_inner[index]))/np.sum(np.abs(e10_inner_w_acnm_with_inner[index] - initial_inner_w_acnm_with_inner[index]))]

w = 0.8
plt.ylabel("Change coefficient", fontsize="large")
plt.xlabel("Model parameters", fontsize="large")
ax.bar(x, y, width=w, color=('blue', 'purple', 'purple', 'orange', 'green', 'green'))

plt.grid()
plt.show()

# %%
fig = plt.figure(figsize=(18, 10))
ax = fig.add_subplot()

plt.title("Average change per parameter", fontsize="xx-large")

x = np.arange(6)
y1 = [np.average(np.abs(e100_outer_w_anm_no_inner[index] - initial_outer_w_anm_no_inner[index])),
      np.average(np.abs(e100_outer_w_anm_with_inner[index] - initial_outer_w_anm_with_inner[index])),
      np.average(np.abs(e100_inner_w_anm_with_inner[index] - initial_inner_w_anm_with_inner[index])),
      np.average(np.abs(e100_outer_w_acnm_no_inner[index] - initial_outer_w_acnm_no_inner[index])),
      np.average(np.abs(e100_outer_w_acnm_with_inner[index] - initial_outer_w_acnm_with_inner[index])),
      np.average(np.abs(e100_inner_w_acnm_with_inner[index] - initial_inner_w_acnm_with_inner[index]))]

y2 = [np.average(np.abs(e10_outer_w_anm_no_inner[index] - initial_outer_w_anm_no_inner[index])),
      np.average(np.abs(e10_outer_w_anm_with_inner[index] - initial_outer_w_anm_with_inner[index])),
      np.average(np.abs(e10_inner_w_anm_with_inner[index] - initial_inner_w_anm_with_inner[index])),
      np.average(np.abs(e10_outer_w_acnm_no_inner[index] - initial_outer_w_acnm_no_inner[index])),
      np.average(np.abs(e10_outer_w_acnm_with_inner[index] - initial_outer_w_acnm_with_inner[index])),
      np.average(np.abs(e10_inner_w_acnm_with_inner[index] - initial_inner_w_acnm_with_inner[index]))]

w = 0.4

plt.ylabel("Average change coefficient")
ax.bar(x - w/2, y1, width = w, label="100 epochs")
ax.bar(x + w/2, y2, width = w, label="10 epochs")

plt.xticks([r for r in range(len(y1))], 
        ['outer_w_anm_no_inner', 'outer_w_anm_with_inner', 'inner_w_anm_with_inner',
     'outer_w_acnm_no_inner', 'outer_w_acnm_with_inner', 'inner_w_acnm_with_inner'])

plt.legend()
plt.grid()
plt.show()

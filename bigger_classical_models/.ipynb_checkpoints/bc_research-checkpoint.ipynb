# %%
import tensorflow as tf
tf.config.experimental.set_visible_devices([], 'GPU')
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xlsxwriter

# %%
tf.random.set_seed(5)
np.random.seed(5)

# %%
def illustrate_train(name, y_label, static_f, adaptive_f, adaptive_nn, adaptive_conv_nn):
    epochs = range(0, len(static_f))
    fig = plt.figure(figsize=(10,7))
    ax = fig.add_subplot()
    plt.title(name, fontsize="xx-large")

    ax.set_ylabel(y_label, fontsize="large")
    ax.set_xlabel('Epochs', fontsize="large")

    ax.plot(epochs, static_f, label='Static Function')
    ax.plot(epochs, adaptive_f, label='Adaptive Function')
    ax.plot(epochs, adaptive_nn, label='Adaptive NN')
    ax.plot(epochs, adaptive_conv_nn, label='Adaptive Conv NN')

    ax.legend()
    
    plt.grid()
    plt.show()

# %%
def illustrate_test(name, static_f, adaptive_f, adaptive_nn, adaptive_conv_nn):
    fig = plt.figure(figsize=(10,7))
    ax = fig.add_subplot()
    
    x = ["Static Function", "Adaptive Function", "Adaptive NN", "Adaptive Conv NN"]
    y = [static_f, adaptive_f, adaptive_nn, adaptive_conv_nn]
    
    plt.title(name, fontsize="xx-large")
    ax.set_ylabel("Accuracy", fontsize="large")
    
    ax.bar(x, y)
    
    plt.grid()
    plt.show()

# %%
workbook = xlsxwriter.Workbook('bc.xlsx')

# %%
def save_data(name, static_f_train, adaptive_f_train, adaptive_nn_train, adaptive_conv_nn_train, 
              static_f_test, adaptive_f_test, adaptive_nn_test, adaptive_conv_nn_test):
    
    epochs = len(static_f_train[0][:])
    worksheet = workbook.add_worksheet(name)
    
    worksheet.write(1, 1, name + " Training Loss")
    worksheet.write(1, 7, name + " Training Accuracy")
    worksheet.write(1, 13, name + " Test Accuracy")
    
    worksheet.write(2, 1, "Epochs")
    worksheet.write(2, 2, "Static Function")
    worksheet.write(2, 3, "Adaptive Function")
    worksheet.write(2, 4, "Adaptive NN")
    worksheet.write(2, 5, "Adaptive Conv NN")
    
    worksheet.write(2, 7, "Epochs")
    worksheet.write(2, 8, "Static Function")
    worksheet.write(2, 9, "Adaptive Function")
    worksheet.write(2, 10, "Adaptive NN")
    worksheet.write(2, 11, "Adaptive Conv NN")
    
    worksheet.write(2, 13, "Static Function")
    worksheet.write(2, 14, "Adaptive Function")
    worksheet.write(2, 15, "Adaptive NN")
    worksheet.write(2, 16, "Adaptive Conv NN")
    
    worksheet.write(3, 13, static_f_test)
    worksheet.write(3, 14, adaptive_f_test)
    worksheet.write(3, 15, adaptive_nn_test)
    worksheet.write(3, 16, adaptive_conv_nn_test)
    
    for i in range(0, epochs):
        worksheet.write(3+i, 1, i+1)
        worksheet.write(3+i, 2, static_f_train[0][i])
        worksheet.write(3+i, 3, adaptive_f_train[0][i])
        worksheet.write(3+i, 4, adaptive_nn_train[0][i])
        worksheet.write(3+i, 5, adaptive_conv_nn_train[0][i])
        
        worksheet.write(3+i, 7, i+1)
        worksheet.write(3+i, 8, static_f_train[1][i])
        worksheet.write(3+i, 9, adaptive_f_train[1][i])
        worksheet.write(3+i, 10, adaptive_nn_train[1][i])
        worksheet.write(3+i, 11, adaptive_conv_nn_train[1][i])
    
    workbook.close()

# %%
class AdaptiveLayer(keras.layers.Layer):
    
    def __init__(self, units, structure=[2, 2], inner_hidden_activation=tf.nn.tanh, 
                 inner_out_activation=lambda x : x, skip_w=0.0):
        super().__init__()
        self.units = units
        self.structure = structure
        self.structure.append(1)
        self.inner_hidden_activation = inner_hidden_activation
        self.inner_out_activation = inner_out_activation
        self.skip_w = skip_w
        
        
    def build(self, input_shape):
        self.outter_w = self.add_weight(shape=(input_shape[-1], self.units), initializer="random_normal")
        self.outter_b = self.add_weight(shape=(self.units), initializer="zeros")
        
        self.inner_w = []
        self.inner_b = []
        for i in range(len(self.structure)):
            if i == 0:
                self.inner_w.append(self.add_weight(shape=(self.units, 1, self.structure[i]), 
                                          initializer=tf.initializers.random_normal(stddev=1.5)))
            else:
                self.inner_w.append(self.add_weight(shape=(self.units, self.structure[i-1], self.structure[i]), 
                                          initializer=tf.initializers.random_normal(stddev=0.9)))
            
            self.inner_b.append(self.add_weight(shape=(self.units, 1, self.structure[i]), initializer="zeros"))
   

    def call(self, inputs):
        z = inputs @ self.outter_w + self.outter_b
        a = tf.expand_dims(tf.transpose(z), axis=-1)
        
        for i in range(len(self.inner_w)-1):
            a = a @ self.inner_w[i] + self.inner_b[i]
            a = self.inner_hidden_activation(a)
        
        a = a @ self.inner_w[len(self.inner_w)-1] + self.inner_b[len(self.inner_w)-1]
        
        a = tf.reshape(tf.transpose(a), shape=(len(inputs), self.units))
        a = self.inner_out_activation(a+z*self.skip_w)
        
        return a
        

    def activation_show(self, inputs):
        inner_z = tf.cast(tf.expand_dims(tf.transpose(inputs), axis=-1), dtype=tf.float32)
        a = tf.expand_dims(tf.transpose(inner_z), axis=-1)
        
        for i in range(len(self.inner_w)-1):
            a = a @ self.inner_w[i] + self.inner_b[i]
            a = self.inner_hidden_activation(a)
        
        a = a @ self.inner_w[len(self.inner_w)-1] + self.inner_b[len(self.inner_w)-1]
        
        a = tf.reshape(tf.transpose(a), shape=(len(inputs), self.units))
        a = self.inner_out_activation(a)
        
        return a

# %%
class AdaptiveLayerConv(keras.layers.Layer):
    
    def __init__(self, units, structure=[4, 8], split=2, inner_hidden_activation=tf.nn.tanh, 
                 inner_out_activation=lambda x : x, skip_w=0.9, noise=0.0):
        super().__init__()
        self.units = units
        self.structure = structure
        self.split = split
        self.inner_hidden_activation = inner_hidden_activation
        self.inner_out_activation = inner_out_activation
        self.skip_w = skip_w
        self.noise = noise
        
        
    def build(self, input_shape):
        
        self.outter_w = []
        self.outter_b = []
        
        for i in range(0, self.split):
            self.outter_w.append(self.add_weight(shape=(input_shape[-1], self.units), 
                                                 initializer="random_normal"))
            self.outter_b.append(self.add_weight(shape=(self.units), initializer="zeros"))
        
        self.inner_conv = []
        for i in range(0, len(self.structure)):
            self.inner_conv.append(keras.layers.Conv1D(self.structure[i], 1, 
                                                       activation=self.inner_hidden_activation))
            
        self.inner_conv.append(keras.layers.AveragePooling1D(pool_size=self.split, data_format='channels_first'))      
        self.inner_conv.append(keras.layers.Conv1D(self.units, 1)) 

   

    def call(self, inputs):
        z = []
        for i in range(0, self.split):
            noise = tf.random.truncated_normal(shape=(self.outter_b[i].shape))
            z.append(inputs @ self.outter_w[i] + self.outter_b[i] + noise*self.noise)
        
        a = tf.cast(z, dtype=tf.float32)
        z = tf.cast(z, dtype=tf.float32)
        
        for i in range(len(self.inner_conv)-2):
            a = self.inner_conv[i](a)
        
        a = self.inner_conv[len(self.inner_conv)-2](tf.transpose(a))
        a = self.inner_conv[len(self.inner_conv)-1](tf.transpose(a))
    
        a = tf.reshape(a, shape=(-1, self.units))
        z_skip = tf.reduce_sum(z, axis=0)/self.split     
        
        a = self.inner_out_activation(a + z_skip*self.skip_w)
        
        return a    

    def activation_show(self, inputs):
        tmp = []
        for i in range(0, self.units):
            tmp.append(inputs)
        
        tmp = tf.cast(tmp, dtype=tf.float32)
        a = tf.expand_dims(tf.transpose(tmp), axis=0)
            
        for i in range(len(self.inner_conv)-2):
            a = self.inner_conv[i](a)
             
        a = self.inner_conv[len(self.inner_conv)-1](a)
        a = tf.reshape(a, shape=(-1, self.units))
        a = self.inner_out_activation(a)
        
        return a

# %%
class AdaptiveModel(keras.Model):
    
    def __init__(self, l=[AdaptiveLayer(2), AdaptiveLayer(1)]):
        super().__init__()
        self.l = l

    def call(self, inputs):
        a = inputs
        for layer in self.l:
            a = layer(a)
        
        return a
        
    def activation_show(self, inputs):
        y = []
        
        for layer in self.l:
            tmp = layer.activation_show(inputs)
            
            for i in range(tmp.shape[-1]):
                y.append(tmp[:, i])
        
        return y

# %%
# dataset

data = pd.read_csv('sonar_data.csv')
data = pd.DataFrame(data).to_numpy()
np.random.shuffle(data)

x = data[:, :-1]
y = data[:, -1]

x = np.array(x, dtype=np.float32)
y = np.array([out == 'M' for out in (y)], dtype=np.float32)

x_train, x_test = x[:160, :], x[160:, :]
y_train, y_test = y[:160], y[160:]

y_train = tf.constant(y_train, shape=(y_train.shape[0], 1))
y_test = tf.constant(y_test, shape=(y_test.shape[0], 1))

# %%
EPOCHS = 200
name = "Sonar Binary Classification"

flag = measurements = 5

static_f_hist = np.zeros(shape=[2, EPOCHS])
adaptive_f_hist = np.zeros(shape=[2, EPOCHS])
adaptive_nn_hist = np.zeros(shape=[2, EPOCHS])
adaptive_conv_nn_hist = np.zeros(shape=[2, EPOCHS])

static_f_test = 0
adaptive_f_test = 0
adaptive_nn_test = 0
adaptive_conv_nn_test = 0

# %%
static_f_model = keras.Sequential([
    keras.layers.Dense(5, activation="relu"),
    keras.layers.Dense(1, activation="sigmoid")
])

# %%
adaptive_f_model = keras.Sequential([
    keras.layers.Dense(5, activation=tf.nn.swish),
    keras.layers.Dense(1, activation="sigmoid")
])

# %%
adaptive_nn_model = AdaptiveModel([
    AdaptiveLayer(5, structure=[2, 1], inner_out_activation=tf.nn.sigmoid, skip_w=0.1),
    AdaptiveLayer(1, structure=[2, 1], inner_out_activation=tf.nn.sigmoid, skip_w=0.1)
])

# %%
adaptive_conv_nn_model = AdaptiveModel([
    AdaptiveLayerConv(5, structure=[2, 4], split=3, skip_w=0, noise=0, inner_out_activation=tf.nn.sigmoid),
    AdaptiveLayerConv(1, structure=[2, 4], skip_w=0, noise=0, inner_out_activation=tf.nn.sigmoid)
])

# %%
static_f_model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.003), 
                       loss="binary_crossentropy", metrics=['accuracy'])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.

# %%
adaptive_f_model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.003), 
                       loss="binary_crossentropy", metrics=['accuracy'])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.

# %%
adaptive_nn_model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.003), 
                       loss="binary_crossentropy", metrics=['accuracy'])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.

# %%
adaptive_conv_nn_model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.003), 
                       loss="binary_crossentropy", metrics=['accuracy'])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.

# %%
hist = static_f_model.fit(x_train, y_train, epochs=EPOCHS, batch_size=64)
# Out:
# Epoch 1/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.8356 - accuracy: 0.4875
# Epoch 2/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7946 - accuracy: 0.4875
# Epoch 3/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7608 - accuracy: 0.5000
# Epoch 4/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7351 - accuracy: 0.5063
# Epoch 5/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7147 - accuracy: 0.5562
# Epoch 6/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7021 - accuracy: 0.5000
# Epoch 7/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6912 - accuracy: 0.5125
# Epoch 8/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6861 - accuracy: 0.5750
# Epoch 9/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6805 - accuracy: 0.6125
# Epoch 10/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6783 - accuracy: 0.5938
# Epoch 11/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6769 - accuracy: 0.6000
# Epoch 12/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6760 - accuracy: 0.6062
# Epoch 13/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6744 - accuracy: 0.6250
# Epoch 14/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6725 - accuracy: 0.6187
# Epoch 15/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6708 - accuracy: 0.6187
# Epoch 16/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6684 - accuracy: 0.6187
# Epoch 17/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6662 - accuracy: 0.6187
# Epoch 18/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6634 - accuracy: 0.6375
# Epoch 19/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6612 - accuracy: 0.6562
# Epoch 20/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6588 - accuracy: 0.6625
# Epoch 21/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6566 - accuracy: 0.6750
# Epoch 22/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6540 - accuracy: 0.6750
# Epoch 23/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6517 - accuracy: 0.6812
# Epoch 24/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6488 - accuracy: 0.6750
# Epoch 25/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6461 - accuracy: 0.6875
# Epoch 26/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6436 - accuracy: 0.6812
# Epoch 27/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6411 - accuracy: 0.6750
# Epoch 28/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6378 - accuracy: 0.6812
# Epoch 29/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6345 - accuracy: 0.7000
# Epoch 30/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6311 - accuracy: 0.6875
# Epoch 31/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6276 - accuracy: 0.6938
# Epoch 32/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6241 - accuracy: 0.7125
# Epoch 33/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6197 - accuracy: 0.7250
# Epoch 34/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6153 - accuracy: 0.7312
# Epoch 35/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6108 - accuracy: 0.7250
# Epoch 36/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6060 - accuracy: 0.7250
# Epoch 37/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5999 - accuracy: 0.7437
# Epoch 38/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5953 - accuracy: 0.7688
# Epoch 39/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5902 - accuracy: 0.7625
# Epoch 40/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5862 - accuracy: 0.7688
# Epoch 41/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5790 - accuracy: 0.7812
# Epoch 42/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5708 - accuracy: 0.7812
# Epoch 43/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5641 - accuracy: 0.7625
# Epoch 44/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5589 - accuracy: 0.7688
# Epoch 45/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5526 - accuracy: 0.7625
# Epoch 46/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5449 - accuracy: 0.7812
# Epoch 47/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5389 - accuracy: 0.7937
# Epoch 48/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5346 - accuracy: 0.7937
# Epoch 49/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5301 - accuracy: 0.7875
# Epoch 50/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5219 - accuracy: 0.8062
# Epoch 51/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5161 - accuracy: 0.7937
# Epoch 52/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5122 - accuracy: 0.7812
# Epoch 53/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5094 - accuracy: 0.7750
# Epoch 54/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5022 - accuracy: 0.7812
# Epoch 55/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4976 - accuracy: 0.7937
# Epoch 56/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4914 - accuracy: 0.8062
# Epoch 57/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4874 - accuracy: 0.8125
# Epoch 58/200
# 3/3 [==============================] - 0s 906us/step - loss: 0.4864 - accuracy: 0.7937
# Epoch 59/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4821 - accuracy: 0.8125
# Epoch 60/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4768 - accuracy: 0.8125
# Epoch 61/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4725 - accuracy: 0.8125
# Epoch 62/200
# 3/3 [==============================] - 0s 980us/step - loss: 0.4688 - accuracy: 0.8188
# Epoch 63/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4653 - accuracy: 0.8125
# Epoch 64/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4617 - accuracy: 0.8188
# Epoch 65/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4585 - accuracy: 0.8188
# Epoch 66/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4554 - accuracy: 0.8188
# Epoch 67/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4516 - accuracy: 0.8125
# Epoch 68/200
# 3/3 [==============================] - 0s 937us/step - loss: 0.4516 - accuracy: 0.8125
# Epoch 69/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4482 - accuracy: 0.8062
# Epoch 70/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4460 - accuracy: 0.8125
# Epoch 71/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4418 - accuracy: 0.8250
# Epoch 72/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4391 - accuracy: 0.8313
# Epoch 73/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4360 - accuracy: 0.8250
# Epoch 74/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4341 - accuracy: 0.8188
# Epoch 75/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4318 - accuracy: 0.8188
# Epoch 76/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4290 - accuracy: 0.8188
# Epoch 77/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4275 - accuracy: 0.8188
# Epoch 78/200
# 3/3 [==============================] - 0s 907us/step - loss: 0.4251 - accuracy: 0.8313
# Epoch 79/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4228 - accuracy: 0.8250
# Epoch 80/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4210 - accuracy: 0.8250
# Epoch 81/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4189 - accuracy: 0.8375
# Epoch 82/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4165 - accuracy: 0.8188
# Epoch 83/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4152 - accuracy: 0.8313
# Epoch 84/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4127 - accuracy: 0.8438
# Epoch 85/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4103 - accuracy: 0.8375
# Epoch 86/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4086 - accuracy: 0.8313
# Epoch 87/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4078 - accuracy: 0.8375
# Epoch 88/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4051 - accuracy: 0.8188
# Epoch 89/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4030 - accuracy: 0.8250
# Epoch 90/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4015 - accuracy: 0.8438
# Epoch 91/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4004 - accuracy: 0.8438
# Epoch 92/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3976 - accuracy: 0.8438
# Epoch 93/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3959 - accuracy: 0.8313
# Epoch 94/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3951 - accuracy: 0.8250
# Epoch 95/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3938 - accuracy: 0.8250
# Epoch 96/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3935 - accuracy: 0.8500
# Epoch 97/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3898 - accuracy: 0.8562
# Epoch 98/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3891 - accuracy: 0.8438
# Epoch 99/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3876 - accuracy: 0.8375
# Epoch 100/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3855 - accuracy: 0.8500
# Epoch 101/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3850 - accuracy: 0.8438
# Epoch 102/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3834 - accuracy: 0.8562
# Epoch 103/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3821 - accuracy: 0.8500
# Epoch 104/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3795 - accuracy: 0.8562
# Epoch 105/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3799 - accuracy: 0.8375
# Epoch 106/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3787 - accuracy: 0.8313
# Epoch 107/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3767 - accuracy: 0.8375
# Epoch 108/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3745 - accuracy: 0.8438
# Epoch 109/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3733 - accuracy: 0.8562
# Epoch 110/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3724 - accuracy: 0.8500
# Epoch 111/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3714 - accuracy: 0.8500
# Epoch 112/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3708 - accuracy: 0.8562
# Epoch 113/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3683 - accuracy: 0.8562
# Epoch 114/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3670 - accuracy: 0.8438
# Epoch 115/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3672 - accuracy: 0.8438
# Epoch 116/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3651 - accuracy: 0.8375
# Epoch 117/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3631 - accuracy: 0.8625
# Epoch 118/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3645 - accuracy: 0.8500
# Epoch 119/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3628 - accuracy: 0.8500
# Epoch 120/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3600 - accuracy: 0.8625
# Epoch 121/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3591 - accuracy: 0.8438
# Epoch 122/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3580 - accuracy: 0.8438
# Epoch 123/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3573 - accuracy: 0.8562
# Epoch 124/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3563 - accuracy: 0.8500
# Epoch 125/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3549 - accuracy: 0.8500
# Epoch 126/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3542 - accuracy: 0.8562
# Epoch 127/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3530 - accuracy: 0.8687
# Epoch 128/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3515 - accuracy: 0.8687
# Epoch 129/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3508 - accuracy: 0.8625
# Epoch 130/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3498 - accuracy: 0.8562
# Epoch 131/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3484 - accuracy: 0.8562
# Epoch 132/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3480 - accuracy: 0.8687
# Epoch 133/200
# 3/3 [==============================] - 0s 937us/step - loss: 0.3464 - accuracy: 0.8562
# Epoch 134/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3458 - accuracy: 0.8625
# Epoch 135/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3444 - accuracy: 0.8625
# Epoch 136/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3432 - accuracy: 0.8750
# Epoch 137/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3426 - accuracy: 0.8625
# Epoch 138/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3416 - accuracy: 0.8625
# Epoch 139/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3400 - accuracy: 0.8750
# Epoch 140/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3390 - accuracy: 0.8625
# Epoch 141/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3430 - accuracy: 0.8687
# Epoch 142/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3382 - accuracy: 0.8687
# Epoch 143/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3376 - accuracy: 0.8625
# Epoch 144/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3369 - accuracy: 0.8750
# Epoch 145/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3346 - accuracy: 0.8750
# Epoch 146/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3335 - accuracy: 0.8687
# Epoch 147/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3337 - accuracy: 0.8813
# Epoch 148/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3326 - accuracy: 0.8750
# Epoch 149/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3318 - accuracy: 0.8750
# Epoch 150/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3300 - accuracy: 0.8750
# Epoch 151/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3294 - accuracy: 0.8750
# Epoch 152/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3282 - accuracy: 0.8687
# Epoch 153/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3281 - accuracy: 0.8750
# Epoch 154/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3274 - accuracy: 0.8687
# Epoch 155/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3274 - accuracy: 0.8625
# Epoch 156/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3255 - accuracy: 0.8750
# Epoch 157/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3244 - accuracy: 0.8750
# Epoch 158/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3239 - accuracy: 0.8625
# Epoch 159/200
# 3/3 [==============================] - 0s 950us/step - loss: 0.3224 - accuracy: 0.8625
# Epoch 160/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3215 - accuracy: 0.8625
# Epoch 161/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3206 - accuracy: 0.8625
# Epoch 162/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3197 - accuracy: 0.8750
# Epoch 163/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3197 - accuracy: 0.8750
# Epoch 164/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3186 - accuracy: 0.8750
# Epoch 165/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3173 - accuracy: 0.8625
# Epoch 166/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3178 - accuracy: 0.8750
# Epoch 167/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3169 - accuracy: 0.8813
# Epoch 168/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3154 - accuracy: 0.8687
# Epoch 169/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3144 - accuracy: 0.8750
# Epoch 170/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3136 - accuracy: 0.8750
# Epoch 171/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3130 - accuracy: 0.8813
# Epoch 172/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3132 - accuracy: 0.8875
# Epoch 173/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3117 - accuracy: 0.8813
# Epoch 174/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3104 - accuracy: 0.8813
# Epoch 175/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3098 - accuracy: 0.8813
# Epoch 176/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3095 - accuracy: 0.8813
# Epoch 177/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3095 - accuracy: 0.8813
# Epoch 178/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3086 - accuracy: 0.8813
# Epoch 179/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3067 - accuracy: 0.8750
# Epoch 180/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3060 - accuracy: 0.8813
# Epoch 181/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3059 - accuracy: 0.8625
# Epoch 182/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3045 - accuracy: 0.8687
# Epoch 183/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3033 - accuracy: 0.8875
# Epoch 184/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3029 - accuracy: 0.8813
# Epoch 185/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3022 - accuracy: 0.8875
# Epoch 186/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3029 - accuracy: 0.8813
# Epoch 187/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3008 - accuracy: 0.8813
# Epoch 188/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3001 - accuracy: 0.8813
# Epoch 189/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2992 - accuracy: 0.8875
# Epoch 190/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2982 - accuracy: 0.8875
# Epoch 191/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2984 - accuracy: 0.8875
# Epoch 192/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2974 - accuracy: 0.8875
# Epoch 193/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2963 - accuracy: 0.8875
# Epoch 194/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2957 - accuracy: 0.8813
# Epoch 195/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2948 - accuracy: 0.8813
# Epoch 196/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2939 - accuracy: 0.8813
# Epoch 197/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2935 - accuracy: 0.8875
# Epoch 198/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2932 - accuracy: 0.8875
# Epoch 199/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2919 - accuracy: 0.8875
# Epoch 200/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2912 - accuracy: 0.8875

# %%
static_f_hist[0][:] += np.array(hist.history["loss"])/measurements
static_f_hist[1][:] += np.array(hist.history["accuracy"])/measurements

# %%
hist = adaptive_f_model.fit(x_train, y_train, epochs=EPOCHS, batch_size=64)
# Out:
# Epoch 1/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7117 - accuracy: 0.4625
# Epoch 2/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7016 - accuracy: 0.5375
# Epoch 3/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6980 - accuracy: 0.5312
# Epoch 4/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6953 - accuracy: 0.5250
# Epoch 5/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6882 - accuracy: 0.5312
# Epoch 6/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6809 - accuracy: 0.5500
# Epoch 7/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6742 - accuracy: 0.5750
# Epoch 8/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6686 - accuracy: 0.6187
# Epoch 9/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6650 - accuracy: 0.6812
# Epoch 10/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6594 - accuracy: 0.7125
# Epoch 11/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6535 - accuracy: 0.6938
# Epoch 12/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6469 - accuracy: 0.6812
# Epoch 13/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6408 - accuracy: 0.7125
# Epoch 14/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6351 - accuracy: 0.7000
# Epoch 15/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6315 - accuracy: 0.6875
# Epoch 16/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6245 - accuracy: 0.6750
# Epoch 17/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6182 - accuracy: 0.7000
# Epoch 18/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6113 - accuracy: 0.7125
# Epoch 19/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6055 - accuracy: 0.7125
# Epoch 20/200
# 3/3 [==============================] - 0s 988us/step - loss: 0.5987 - accuracy: 0.7250
# Epoch 21/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5920 - accuracy: 0.7375
# Epoch 22/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5844 - accuracy: 0.7250
# Epoch 23/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5779 - accuracy: 0.7188
# Epoch 24/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5711 - accuracy: 0.7312
# Epoch 25/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5636 - accuracy: 0.7312
# Epoch 26/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5565 - accuracy: 0.7375
# Epoch 27/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5497 - accuracy: 0.7437
# Epoch 28/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5417 - accuracy: 0.7500
# Epoch 29/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5344 - accuracy: 0.7625
# Epoch 30/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5270 - accuracy: 0.7688
# Epoch 31/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5196 - accuracy: 0.7875
# Epoch 32/200
# 3/3 [==============================] - 0s 982us/step - loss: 0.5142 - accuracy: 0.7750
# Epoch 33/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5064 - accuracy: 0.7937
# Epoch 34/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5000 - accuracy: 0.7812
# Epoch 35/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4945 - accuracy: 0.7563
# Epoch 36/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4884 - accuracy: 0.7625
# Epoch 37/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4810 - accuracy: 0.7937
# Epoch 38/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4786 - accuracy: 0.8188
# Epoch 39/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4749 - accuracy: 0.8250
# Epoch 40/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4721 - accuracy: 0.8250
# Epoch 41/200
# 3/3 [==============================] - 0s 975us/step - loss: 0.4631 - accuracy: 0.8250
# Epoch 42/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4596 - accuracy: 0.7812
# Epoch 43/200
# 3/3 [==============================] - 0s 888us/step - loss: 0.4572 - accuracy: 0.7875
# Epoch 44/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4514 - accuracy: 0.7937
# Epoch 45/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4474 - accuracy: 0.8188
# Epoch 46/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4447 - accuracy: 0.8250
# Epoch 47/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4405 - accuracy: 0.8188
# Epoch 48/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4374 - accuracy: 0.8250
# Epoch 49/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4343 - accuracy: 0.8188
# Epoch 50/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4300 - accuracy: 0.8125
# Epoch 51/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4289 - accuracy: 0.8062
# Epoch 52/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4268 - accuracy: 0.7937
# Epoch 53/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4273 - accuracy: 0.8000
# Epoch 54/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4201 - accuracy: 0.8188
# Epoch 55/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4178 - accuracy: 0.8188
# Epoch 56/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4154 - accuracy: 0.8125
# Epoch 57/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4140 - accuracy: 0.8125
# Epoch 58/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4178 - accuracy: 0.8250
# Epoch 59/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4132 - accuracy: 0.8188
# Epoch 60/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4086 - accuracy: 0.8375
# Epoch 61/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4060 - accuracy: 0.8188
# Epoch 62/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4037 - accuracy: 0.8313
# Epoch 63/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4018 - accuracy: 0.8125
# Epoch 64/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4022 - accuracy: 0.8250
# Epoch 65/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3988 - accuracy: 0.8188
# Epoch 66/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3966 - accuracy: 0.8313
# Epoch 67/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3953 - accuracy: 0.8375
# Epoch 68/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3989 - accuracy: 0.8313
# Epoch 69/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3929 - accuracy: 0.8313
# Epoch 70/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3943 - accuracy: 0.8313
# Epoch 71/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3926 - accuracy: 0.8188
# Epoch 72/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3885 - accuracy: 0.8188
# Epoch 73/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3880 - accuracy: 0.8313
# Epoch 74/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3886 - accuracy: 0.8250
# Epoch 75/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3869 - accuracy: 0.8313
# Epoch 76/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3833 - accuracy: 0.8188
# Epoch 77/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3847 - accuracy: 0.8250
# Epoch 78/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3844 - accuracy: 0.8250
# Epoch 79/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3802 - accuracy: 0.8250
# Epoch 80/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3794 - accuracy: 0.8313
# Epoch 81/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3783 - accuracy: 0.8250
# Epoch 82/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3776 - accuracy: 0.8250
# Epoch 83/200
# 3/3 [==============================] - 0s 981us/step - loss: 0.3774 - accuracy: 0.8313
# Epoch 84/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3749 - accuracy: 0.8375
# Epoch 85/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3740 - accuracy: 0.8250
# Epoch 86/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3736 - accuracy: 0.8313
# Epoch 87/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3751 - accuracy: 0.8250
# Epoch 88/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3713 - accuracy: 0.8375
# Epoch 89/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3701 - accuracy: 0.8375
# Epoch 90/200
# 3/3 [==============================] - 0s 978us/step - loss: 0.3705 - accuracy: 0.8438
# Epoch 91/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3700 - accuracy: 0.8375
# Epoch 92/200
# 3/3 [==============================] - 0s 963us/step - loss: 0.3671 - accuracy: 0.8313
# Epoch 93/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3676 - accuracy: 0.8188
# Epoch 94/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3670 - accuracy: 0.8375
# Epoch 95/200
# 3/3 [==============================] - 0s 992us/step - loss: 0.3661 - accuracy: 0.8313
# Epoch 96/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3686 - accuracy: 0.8313
# Epoch 97/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3633 - accuracy: 0.8438
# Epoch 98/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3650 - accuracy: 0.8125
# Epoch 99/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3646 - accuracy: 0.8250
# Epoch 100/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3617 - accuracy: 0.8438
# Epoch 101/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3618 - accuracy: 0.8438
# Epoch 102/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3607 - accuracy: 0.8438
# Epoch 103/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3608 - accuracy: 0.8500
# Epoch 104/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3582 - accuracy: 0.8438
# Epoch 105/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3603 - accuracy: 0.8313
# Epoch 106/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3600 - accuracy: 0.8438
# Epoch 107/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3574 - accuracy: 0.8375
# Epoch 108/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3557 - accuracy: 0.8438
# Epoch 109/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3557 - accuracy: 0.8562
# Epoch 110/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3555 - accuracy: 0.8562
# Epoch 111/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3542 - accuracy: 0.8500
# Epoch 112/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3543 - accuracy: 0.8375
# Epoch 113/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3530 - accuracy: 0.8438
# Epoch 114/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3523 - accuracy: 0.8438
# Epoch 115/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3518 - accuracy: 0.8438
# Epoch 116/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3513 - accuracy: 0.8375
# Epoch 117/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3508 - accuracy: 0.8438
# Epoch 118/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3520 - accuracy: 0.8500
# Epoch 119/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3507 - accuracy: 0.8438
# Epoch 120/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3491 - accuracy: 0.8375
# Epoch 121/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3482 - accuracy: 0.8438
# Epoch 122/200
# 3/3 [==============================] - 0s 949us/step - loss: 0.3470 - accuracy: 0.8500
# Epoch 123/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3481 - accuracy: 0.8562
# Epoch 124/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3476 - accuracy: 0.8562
# Epoch 125/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3454 - accuracy: 0.8500
# Epoch 126/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3465 - accuracy: 0.8438
# Epoch 127/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3456 - accuracy: 0.8438
# Epoch 128/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3432 - accuracy: 0.8438
# Epoch 129/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3447 - accuracy: 0.8562
# Epoch 130/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3447 - accuracy: 0.8562
# Epoch 131/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3422 - accuracy: 0.8562
# Epoch 132/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3433 - accuracy: 0.8562
# Epoch 133/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3423 - accuracy: 0.8438
# Epoch 134/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3410 - accuracy: 0.8500
# Epoch 135/200
# 3/3 [==============================] - 0s 965us/step - loss: 0.3408 - accuracy: 0.8438
# Epoch 136/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3401 - accuracy: 0.8562
# Epoch 137/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3399 - accuracy: 0.8625
# Epoch 138/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3389 - accuracy: 0.8500
# Epoch 139/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3381 - accuracy: 0.8500
# Epoch 140/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3380 - accuracy: 0.8500
# Epoch 141/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3426 - accuracy: 0.8375
# Epoch 142/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3387 - accuracy: 0.8500
# Epoch 143/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3400 - accuracy: 0.8625
# Epoch 144/200
# 3/3 [==============================] - 0s 979us/step - loss: 0.3376 - accuracy: 0.8625
# Epoch 145/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3354 - accuracy: 0.8500
# Epoch 146/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3362 - accuracy: 0.8500
# Epoch 147/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3360 - accuracy: 0.8500
# Epoch 148/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3338 - accuracy: 0.8438
# Epoch 149/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3366 - accuracy: 0.8500
# Epoch 150/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3346 - accuracy: 0.8562
# Epoch 151/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3329 - accuracy: 0.8562
# Epoch 152/200
# 3/3 [==============================] - 0s 968us/step - loss: 0.3339 - accuracy: 0.8562
# Epoch 153/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3355 - accuracy: 0.8750
# Epoch 154/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3312 - accuracy: 0.8562
# Epoch 155/200
# 3/3 [==============================] - 0s 970us/step - loss: 0.3353 - accuracy: 0.8562
# Epoch 156/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3359 - accuracy: 0.8500
# Epoch 157/200
# 3/3 [==============================] - 0s 975us/step - loss: 0.3318 - accuracy: 0.8562
# Epoch 158/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3329 - accuracy: 0.8562
# Epoch 159/200
# 3/3 [==============================] - 0s 988us/step - loss: 0.3315 - accuracy: 0.8562
# Epoch 160/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3296 - accuracy: 0.8562
# Epoch 161/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3295 - accuracy: 0.8500
# Epoch 162/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3289 - accuracy: 0.8562
# Epoch 163/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3287 - accuracy: 0.8500
# Epoch 164/200
# 3/3 [==============================] - 0s 994us/step - loss: 0.3269 - accuracy: 0.8562
# Epoch 165/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3276 - accuracy: 0.8562
# Epoch 166/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3304 - accuracy: 0.8750
# Epoch 167/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3276 - accuracy: 0.8562
# Epoch 168/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3272 - accuracy: 0.8500
# Epoch 169/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3277 - accuracy: 0.8438
# Epoch 170/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3253 - accuracy: 0.8500
# Epoch 171/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3241 - accuracy: 0.8562
# Epoch 172/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3269 - accuracy: 0.8562
# Epoch 173/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3253 - accuracy: 0.8687
# Epoch 174/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3244 - accuracy: 0.8500
# Epoch 175/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3255 - accuracy: 0.8438
# Epoch 176/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3248 - accuracy: 0.8500
# Epoch 177/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3230 - accuracy: 0.8438
# Epoch 178/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3241 - accuracy: 0.8562
# Epoch 179/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3221 - accuracy: 0.8562
# Epoch 180/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3229 - accuracy: 0.8500
# Epoch 181/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3234 - accuracy: 0.8562
# Epoch 182/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3213 - accuracy: 0.8562
# Epoch 183/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3194 - accuracy: 0.8562
# Epoch 184/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3209 - accuracy: 0.8687
# Epoch 185/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3205 - accuracy: 0.8750
# Epoch 186/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3240 - accuracy: 0.8500
# Epoch 187/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3198 - accuracy: 0.8438
# Epoch 188/200
# 3/3 [==============================] - 0s 954us/step - loss: 0.3190 - accuracy: 0.8562
# Epoch 189/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3176 - accuracy: 0.8562
# Epoch 190/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3175 - accuracy: 0.8562
# Epoch 191/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3183 - accuracy: 0.8562
# Epoch 192/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3174 - accuracy: 0.8562
# Epoch 193/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3164 - accuracy: 0.8562
# Epoch 194/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3172 - accuracy: 0.8562
# Epoch 195/200
# 3/3 [==============================] - 0s 997us/step - loss: 0.3167 - accuracy: 0.8562
# Epoch 196/200
# 3/3 [==============================] - 0s 944us/step - loss: 0.3148 - accuracy: 0.8562
# Epoch 197/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3158 - accuracy: 0.8625
# Epoch 198/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3162 - accuracy: 0.8625
# Epoch 199/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3141 - accuracy: 0.8562
# Epoch 200/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3137 - accuracy: 0.8562

# %%
adaptive_f_hist[0][:] += np.array(hist.history["loss"])/measurements
adaptive_f_hist[1][:] += np.array(hist.history["accuracy"])/measurements

# %%
hist = adaptive_nn_model.fit(x_train, y_train, epochs=EPOCHS, batch_size=64)
# Out:
# Epoch 1/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6935 - accuracy: 0.4875
# Epoch 2/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6931 - accuracy: 0.4875
# Epoch 3/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6931 - accuracy: 0.5125
# Epoch 4/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6931 - accuracy: 0.5125
# Epoch 5/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6929 - accuracy: 0.5125
# Epoch 6/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6928 - accuracy: 0.5125
# Epoch 7/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6928 - accuracy: 0.5125
# Epoch 8/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6928 - accuracy: 0.5125
# Epoch 9/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6928 - accuracy: 0.5125
# Epoch 10/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6927 - accuracy: 0.5125
# Epoch 11/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6927 - accuracy: 0.5125
# Epoch 12/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6926 - accuracy: 0.5125
# Epoch 13/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6927 - accuracy: 0.5125
# Epoch 14/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6926 - accuracy: 0.5125
# Epoch 15/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6927 - accuracy: 0.5125
# Epoch 16/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6925 - accuracy: 0.5125
# Epoch 17/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6924 - accuracy: 0.5125
# Epoch 18/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6924 - accuracy: 0.5125
# Epoch 19/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6924 - accuracy: 0.5125
# Epoch 20/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6922 - accuracy: 0.5125
# Epoch 21/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6921 - accuracy: 0.5125
# Epoch 22/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6920 - accuracy: 0.5125
# Epoch 23/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6918 - accuracy: 0.5125
# Epoch 24/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6917 - accuracy: 0.5125
# Epoch 25/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6914 - accuracy: 0.5125
# Epoch 26/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6912 - accuracy: 0.5125
# Epoch 27/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6909 - accuracy: 0.5125
# Epoch 28/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6904 - accuracy: 0.5125
# Epoch 29/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6899 - accuracy: 0.5125
# Epoch 30/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6892 - accuracy: 0.5125
# Epoch 31/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6884 - accuracy: 0.5125
# Epoch 32/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6874 - accuracy: 0.5125
# Epoch 33/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6861 - accuracy: 0.5125
# Epoch 34/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6845 - accuracy: 0.5188
# Epoch 35/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6827 - accuracy: 0.5500
# Epoch 36/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6804 - accuracy: 0.5625
# Epoch 37/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6773 - accuracy: 0.6687
# Epoch 38/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6743 - accuracy: 0.7000
# Epoch 39/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6699 - accuracy: 0.8062
# Epoch 40/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6663 - accuracy: 0.8062
# Epoch 41/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6605 - accuracy: 0.8250
# Epoch 42/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6543 - accuracy: 0.8250
# Epoch 43/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6470 - accuracy: 0.8313
# Epoch 44/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6385 - accuracy: 0.8250
# Epoch 45/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6287 - accuracy: 0.8250
# Epoch 46/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6188 - accuracy: 0.8313
# Epoch 47/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6077 - accuracy: 0.8313
# Epoch 48/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5961 - accuracy: 0.8375
# Epoch 49/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5840 - accuracy: 0.8375
# Epoch 50/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5712 - accuracy: 0.8313
# Epoch 51/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5598 - accuracy: 0.8562
# Epoch 52/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5482 - accuracy: 0.8625
# Epoch 53/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5342 - accuracy: 0.8562
# Epoch 54/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5250 - accuracy: 0.8625
# Epoch 55/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5131 - accuracy: 0.8562
# Epoch 56/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5033 - accuracy: 0.8562
# Epoch 57/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4973 - accuracy: 0.8562
# Epoch 58/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4864 - accuracy: 0.8562
# Epoch 59/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4773 - accuracy: 0.8625
# Epoch 60/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4683 - accuracy: 0.8625
# Epoch 61/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4608 - accuracy: 0.8687
# Epoch 62/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4561 - accuracy: 0.8562
# Epoch 63/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4483 - accuracy: 0.8750
# Epoch 64/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4429 - accuracy: 0.8625
# Epoch 65/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4377 - accuracy: 0.8750
# Epoch 66/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4329 - accuracy: 0.8750
# Epoch 67/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4268 - accuracy: 0.8813
# Epoch 68/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4316 - accuracy: 0.8687
# Epoch 69/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4138 - accuracy: 0.8875
# Epoch 70/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4315 - accuracy: 0.8375
# Epoch 71/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4148 - accuracy: 0.8813
# Epoch 72/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4332 - accuracy: 0.8500
# Epoch 73/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4089 - accuracy: 0.8813
# Epoch 74/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4222 - accuracy: 0.8375
# Epoch 75/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3982 - accuracy: 0.8750
# Epoch 76/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4013 - accuracy: 0.8750
# Epoch 77/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3988 - accuracy: 0.8750
# Epoch 78/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4046 - accuracy: 0.8562
# Epoch 79/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3871 - accuracy: 0.8875
# Epoch 80/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3821 - accuracy: 0.9000
# Epoch 81/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3851 - accuracy: 0.8687
# Epoch 82/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3752 - accuracy: 0.8938
# Epoch 83/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3753 - accuracy: 0.8938
# Epoch 84/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3672 - accuracy: 0.9000
# Epoch 85/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3687 - accuracy: 0.8750
# Epoch 86/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3626 - accuracy: 0.9000
# Epoch 87/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3612 - accuracy: 0.9000
# Epoch 88/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3620 - accuracy: 0.8938
# Epoch 89/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3530 - accuracy: 0.9000
# Epoch 90/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3610 - accuracy: 0.8875
# Epoch 91/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3500 - accuracy: 0.9000
# Epoch 92/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3479 - accuracy: 0.9062
# Epoch 93/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3448 - accuracy: 0.9062
# Epoch 94/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3435 - accuracy: 0.9062
# Epoch 95/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3438 - accuracy: 0.9125
# Epoch 96/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3407 - accuracy: 0.9125
# Epoch 97/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3379 - accuracy: 0.9125
# Epoch 98/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3367 - accuracy: 0.9125
# Epoch 99/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3314 - accuracy: 0.9250
# Epoch 100/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3295 - accuracy: 0.9187
# Epoch 101/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3277 - accuracy: 0.9250
# Epoch 102/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3229 - accuracy: 0.9250
# Epoch 103/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3200 - accuracy: 0.9250
# Epoch 104/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3160 - accuracy: 0.9250
# Epoch 105/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3193 - accuracy: 0.9125
# Epoch 106/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3136 - accuracy: 0.9250
# Epoch 107/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3108 - accuracy: 0.9250
# Epoch 108/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3085 - accuracy: 0.9250
# Epoch 109/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3072 - accuracy: 0.9250
# Epoch 110/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3037 - accuracy: 0.9250
# Epoch 111/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3029 - accuracy: 0.9250
# Epoch 112/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3022 - accuracy: 0.9375
# Epoch 113/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2991 - accuracy: 0.9250
# Epoch 114/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2957 - accuracy: 0.9312
# Epoch 115/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2950 - accuracy: 0.9312
# Epoch 116/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2959 - accuracy: 0.9250
# Epoch 117/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2907 - accuracy: 0.9312
# Epoch 118/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2881 - accuracy: 0.9375
# Epoch 119/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2841 - accuracy: 0.9375
# Epoch 120/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2838 - accuracy: 0.9375
# Epoch 121/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2812 - accuracy: 0.9375
# Epoch 122/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2803 - accuracy: 0.9375
# Epoch 123/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2810 - accuracy: 0.9312
# Epoch 124/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2780 - accuracy: 0.9312
# Epoch 125/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2775 - accuracy: 0.9375
# Epoch 126/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2739 - accuracy: 0.9375
# Epoch 127/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2794 - accuracy: 0.9312
# Epoch 128/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2732 - accuracy: 0.9375
# Epoch 129/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2705 - accuracy: 0.9375
# Epoch 130/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2715 - accuracy: 0.9312
# Epoch 131/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2673 - accuracy: 0.9375
# Epoch 132/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2677 - accuracy: 0.9375
# Epoch 133/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2652 - accuracy: 0.9375
# Epoch 134/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2649 - accuracy: 0.9375
# Epoch 135/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2626 - accuracy: 0.9375
# Epoch 136/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2616 - accuracy: 0.9375
# Epoch 137/200
# 3/3 [==============================] - 0s 986us/step - loss: 0.2601 - accuracy: 0.9375
# Epoch 138/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2593 - accuracy: 0.9375
# Epoch 139/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2580 - accuracy: 0.9375
# Epoch 140/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2569 - accuracy: 0.9375
# Epoch 141/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2543 - accuracy: 0.9375
# Epoch 142/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2528 - accuracy: 0.9438
# Epoch 143/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2527 - accuracy: 0.9375
# Epoch 144/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2533 - accuracy: 0.9438
# Epoch 145/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2523 - accuracy: 0.9438
# Epoch 146/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2570 - accuracy: 0.9438
# Epoch 147/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2545 - accuracy: 0.9375
# Epoch 148/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2478 - accuracy: 0.9375
# Epoch 149/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2461 - accuracy: 0.9438
# Epoch 150/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2434 - accuracy: 0.9438
# Epoch 151/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2444 - accuracy: 0.9438
# Epoch 152/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2418 - accuracy: 0.9438
# Epoch 153/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2423 - accuracy: 0.9438
# Epoch 154/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2398 - accuracy: 0.9438
# Epoch 155/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2397 - accuracy: 0.9438
# Epoch 156/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2389 - accuracy: 0.9438
# Epoch 157/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2378 - accuracy: 0.9438
# Epoch 158/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2371 - accuracy: 0.9438
# Epoch 159/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2364 - accuracy: 0.9438
# Epoch 160/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2360 - accuracy: 0.9438
# Epoch 161/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2353 - accuracy: 0.9438
# Epoch 162/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2347 - accuracy: 0.9438
# Epoch 163/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2342 - accuracy: 0.9438
# Epoch 164/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2339 - accuracy: 0.9438
# Epoch 165/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2332 - accuracy: 0.9438
# Epoch 166/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2328 - accuracy: 0.9438
# Epoch 167/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2324 - accuracy: 0.9438
# Epoch 168/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2320 - accuracy: 0.9438
# Epoch 169/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2315 - accuracy: 0.9438
# Epoch 170/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2310 - accuracy: 0.9438
# Epoch 171/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2307 - accuracy: 0.9438
# Epoch 172/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2303 - accuracy: 0.9438
# Epoch 173/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2298 - accuracy: 0.9438
# Epoch 174/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2295 - accuracy: 0.9438
# Epoch 175/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2291 - accuracy: 0.9438
# Epoch 176/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2288 - accuracy: 0.9438
# Epoch 177/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2283 - accuracy: 0.9438
# Epoch 178/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2280 - accuracy: 0.9438
# Epoch 179/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2276 - accuracy: 0.9438
# Epoch 180/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2272 - accuracy: 0.9438
# Epoch 181/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2269 - accuracy: 0.9438
# Epoch 182/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2266 - accuracy: 0.9438
# Epoch 183/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2263 - accuracy: 0.9438
# Epoch 184/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2259 - accuracy: 0.9438
# Epoch 185/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2256 - accuracy: 0.9438
# Epoch 186/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2254 - accuracy: 0.9438
# Epoch 187/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2250 - accuracy: 0.9438
# Epoch 188/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2247 - accuracy: 0.9438
# Epoch 189/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2245 - accuracy: 0.9438
# Epoch 190/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2242 - accuracy: 0.9438
# Epoch 191/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2239 - accuracy: 0.9438
# Epoch 192/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2236 - accuracy: 0.9438
# Epoch 193/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2233 - accuracy: 0.9438
# Epoch 194/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2231 - accuracy: 0.9438
# Epoch 195/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2227 - accuracy: 0.9438
# Epoch 196/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2225 - accuracy: 0.9438
# Epoch 197/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2223 - accuracy: 0.9438
# Epoch 198/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2221 - accuracy: 0.9438
# Epoch 199/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2218 - accuracy: 0.9438
# Epoch 200/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2216 - accuracy: 0.9438

# %%
adaptive_nn_hist[0][:] += np.array(hist.history["loss"])/measurements
adaptive_nn_hist[1][:] += np.array(hist.history["accuracy"])/measurements

# %%
hist = adaptive_conv_nn_model.fit(x_train, y_train, epochs=EPOCHS, batch_size=64)
# Out:
# Epoch 1/200
# (3, None, 5)
# (2, None, 1)
# (3, None, 5)
# (2, None, 1)
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6948 - accuracy: 0.4875
# Epoch 2/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6932 - accuracy: 0.4875
# Epoch 3/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6928 - accuracy: 0.5125
# Epoch 4/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6934 - accuracy: 0.5125
# Epoch 5/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6931 - accuracy: 0.5125
# Epoch 6/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6930 - accuracy: 0.5125
# Epoch 7/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6929 - accuracy: 0.5125
# Epoch 8/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6925 - accuracy: 0.5125
# Epoch 9/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6925 - accuracy: 0.5125
# Epoch 10/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6921 - accuracy: 0.5125
# Epoch 11/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6920 - accuracy: 0.5125
# Epoch 12/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6914 - accuracy: 0.5125
# Epoch 13/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6914 - accuracy: 0.5125
# Epoch 14/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6905 - accuracy: 0.5437
# Epoch 15/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6902 - accuracy: 0.5188
# Epoch 16/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6887 - accuracy: 0.5125
# Epoch 17/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6874 - accuracy: 0.5688
# Epoch 18/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6858 - accuracy: 0.5938
# Epoch 19/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6836 - accuracy: 0.6812
# Epoch 20/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6803 - accuracy: 0.6875
# Epoch 21/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6764 - accuracy: 0.6875
# Epoch 22/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6713 - accuracy: 0.6750
# Epoch 23/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6646 - accuracy: 0.6875
# Epoch 24/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6575 - accuracy: 0.7750
# Epoch 25/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6469 - accuracy: 0.8125
# Epoch 26/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6340 - accuracy: 0.8188
# Epoch 27/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6209 - accuracy: 0.7875
# Epoch 28/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6036 - accuracy: 0.7875
# Epoch 29/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5841 - accuracy: 0.8250
# Epoch 30/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5619 - accuracy: 0.8313
# Epoch 31/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5403 - accuracy: 0.8250
# Epoch 32/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5154 - accuracy: 0.8125
# Epoch 33/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4946 - accuracy: 0.8375
# Epoch 34/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4760 - accuracy: 0.8250
# Epoch 35/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4529 - accuracy: 0.8375
# Epoch 36/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4291 - accuracy: 0.8438
# Epoch 37/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4166 - accuracy: 0.8313
# Epoch 38/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4178 - accuracy: 0.8375
# Epoch 39/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3893 - accuracy: 0.8562
# Epoch 40/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4027 - accuracy: 0.8313
# Epoch 41/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3762 - accuracy: 0.8438
# Epoch 42/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3671 - accuracy: 0.8500
# Epoch 43/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3809 - accuracy: 0.8438
# Epoch 44/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3545 - accuracy: 0.8750
# Epoch 45/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3766 - accuracy: 0.8438
# Epoch 46/200
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3441 - accuracy: 0.8500
# Epoch 47/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3674 - accuracy: 0.8438
# Epoch 48/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3495 - accuracy: 0.8562
# Epoch 49/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3499 - accuracy: 0.8562
# Epoch 50/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3415 - accuracy: 0.8625
# Epoch 51/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3479 - accuracy: 0.8687
# Epoch 52/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3452 - accuracy: 0.8562
# Epoch 53/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3325 - accuracy: 0.8750
# Epoch 54/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3379 - accuracy: 0.8813
# Epoch 55/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3291 - accuracy: 0.8813
# Epoch 56/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3417 - accuracy: 0.8500
# Epoch 57/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3388 - accuracy: 0.8813
# Epoch 58/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3248 - accuracy: 0.8938
# Epoch 59/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3207 - accuracy: 0.8750
# Epoch 60/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3140 - accuracy: 0.8938
# Epoch 61/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3137 - accuracy: 0.9062
# Epoch 62/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3113 - accuracy: 0.9062
# Epoch 63/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3102 - accuracy: 0.8875
# Epoch 64/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3057 - accuracy: 0.9000
# Epoch 65/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3093 - accuracy: 0.9000
# Epoch 66/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3014 - accuracy: 0.9062
# Epoch 67/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3018 - accuracy: 0.9000
# Epoch 68/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3132 - accuracy: 0.8938
# Epoch 69/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3044 - accuracy: 0.8938
# Epoch 70/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3074 - accuracy: 0.8813
# Epoch 71/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3079 - accuracy: 0.8875
# Epoch 72/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2969 - accuracy: 0.9125
# Epoch 73/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2904 - accuracy: 0.9062
# Epoch 74/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3004 - accuracy: 0.8875
# Epoch 75/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2902 - accuracy: 0.9125
# Epoch 76/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2989 - accuracy: 0.9062
# Epoch 77/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2872 - accuracy: 0.9125
# Epoch 78/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2840 - accuracy: 0.9125
# Epoch 79/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2832 - accuracy: 0.9125
# Epoch 80/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2828 - accuracy: 0.9000
# Epoch 81/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2774 - accuracy: 0.9250
# Epoch 82/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2772 - accuracy: 0.9187
# Epoch 83/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2721 - accuracy: 0.9187
# Epoch 84/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2725 - accuracy: 0.9250
# Epoch 85/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2704 - accuracy: 0.9187
# Epoch 86/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2669 - accuracy: 0.9187
# Epoch 87/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2673 - accuracy: 0.9187
# Epoch 88/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2670 - accuracy: 0.9187
# Epoch 89/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2602 - accuracy: 0.9250
# Epoch 90/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2663 - accuracy: 0.9250
# Epoch 91/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2622 - accuracy: 0.9250
# Epoch 92/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2618 - accuracy: 0.9187
# Epoch 93/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2689 - accuracy: 0.9250
# Epoch 94/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2600 - accuracy: 0.9062
# Epoch 95/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2815 - accuracy: 0.8938
# Epoch 96/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3221 - accuracy: 0.8562
# Epoch 97/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2547 - accuracy: 0.9187
# Epoch 98/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2961 - accuracy: 0.8938
# Epoch 99/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2833 - accuracy: 0.9062
# Epoch 100/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2578 - accuracy: 0.9187
# Epoch 101/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2649 - accuracy: 0.9125
# Epoch 102/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2950 - accuracy: 0.8875
# Epoch 103/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2525 - accuracy: 0.9250
# Epoch 104/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2818 - accuracy: 0.8938
# Epoch 105/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2493 - accuracy: 0.9250
# Epoch 106/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2526 - accuracy: 0.9250
# Epoch 107/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2456 - accuracy: 0.9312
# Epoch 108/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2437 - accuracy: 0.9312
# Epoch 109/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2448 - accuracy: 0.9250
# Epoch 110/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2429 - accuracy: 0.9250
# Epoch 111/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2423 - accuracy: 0.9250
# Epoch 112/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2412 - accuracy: 0.9312
# Epoch 113/200
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2400 - accuracy: 0.9250
# Epoch 114/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2412 - accuracy: 0.9312
# Epoch 115/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2389 - accuracy: 0.9375
# Epoch 116/200
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2456 - accuracy: 0.9312
# Epoch 117/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2532 - accuracy: 0.9219
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 hist = adaptive_conv_nn_model.fit(x_train, y_train, epochs=EPOCHS, batch_size=64)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/keras/src/engine/training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
adaptive_conv_nn_hist[0][:] += np.array(hist.history["loss"])/measurements
adaptive_conv_nn_hist[1][:] += np.array(hist.history["accuracy"])/measurements

# %%
static_f_test += static_f_model.evaluate(x_test, y_test)[1]/measurements
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5101 - accuracy: 0.8511

# %%
adaptive_f_test += adaptive_f_model.evaluate(x_test, y_test)[1]/measurements
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5091 - accuracy: 0.7447

# %%
adaptive_nn_test += adaptive_nn_model.evaluate(x_test, y_test)[1]/measurements
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3419 - accuracy: 0.8936

# %%
adaptive_conv_nn_test += adaptive_conv_nn_model.evaluate(x_test, y_test)[1]/measurements
flag -= 1
if(flag == 0):
    print("---------FINISH---------")
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3044 - accuracy: 0.8936

# %%
print("Static Function model\nTest accuracy : ", static_f_test)
print("\nAdaptive Function model\nTest accuracy : ", adaptive_f_test)
print("\nAdaptive NN model\nTest accuracy : ", adaptive_nn_test)
print("\nAdaptive Conv NN model\nTest accuracy : ", adaptive_conv_nn_test)
# Out:
# Static Function model
# Test accuracy :  0.7957447052001952
#
# Adaptive Function model
# Test accuracy :  0.7914893865585326
#
# Adaptive NN model
# Test accuracy :  0.8808510780334473
#
# Adaptive Conv NN model
# Test accuracy :  0.8936170339584352

# %%
illustrate_train(name+" Training Loss", "Loss", static_f_hist[0][:], 
                 adaptive_f_hist[0][:], adaptive_nn_hist[0][:], adaptive_conv_nn_hist[0][:])

# %%
illustrate_train(name + " Training Accuracy", "Accuracy", static_f_hist[1][:], 
                 adaptive_f_hist[1][:], adaptive_nn_hist[1][:], adaptive_conv_nn_hist[1][:])

# %%
illustrate_test(name + " Test Accuracy", 
                static_f_test, adaptive_f_test, adaptive_nn_test, adaptive_conv_nn_test)

# %%
save_data(name, static_f_hist, adaptive_f_hist, adaptive_nn_hist, 
          adaptive_conv_nn_hist, static_f_test, adaptive_f_test, adaptive_nn_test, adaptive_conv_nn_test)
